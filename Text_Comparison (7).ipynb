# %%
# !git clone https://github.com/DanielLiangAjj/DBMI_research_profile_crawler.git
# Out:
# Cloning into 'DBMI_research_profile_crawler'...
# remote: Enumerating objects: 2492, done.
# remote: Counting objects: 100% (1043/1043), done.
# remote: Compressing objects: 100% (939/939), done.
# Receiving objects: 100% (2492/2492), 56.43 MiB | 24.04 MiB/s, done.
# remote: Total 2492 (delta 178), reused 920 (delta 101), pack-reused 1449 (from 1)
# Resolving deltas: 100% (248/248), done.
# Updating files: 100% (2279/2279), done.

# %%
# !pip install nltk rouge-score
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=76d09b5d862f1c08b6a5b08f6ec89d09ccaa246560017d33547b174945fdfe4f
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %% [markdown]
# # **Data Preparation & Parsing**

# %%
import nltk
import json
import re
import csv
import os
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
candidate_path = '/content/DBMI_research_profile_crawler/Research Overview'
comparison_csv_path = '/content/DBMI_research_profile_crawler/columbia_research_faculty_extracted.csv'
ed_gpt_path = '/content/DBMI_research_profile_crawler/results_gpt_ed.json'
ed_scraper_path = '/content/DBMI_research_profile_crawler/results_scraper_ed.json'

# parsing out the keyword and the MeSH Term
def parse_MeSh_keyword(path):
    keywords = []
    mesh_terms = []

    with open(path, 'r', encoding='utf-8') as file:
        data = json.load(file)

    for article in data:
        keywords.extend(article.get('Keywords', []))
        mesh_terms.extend(article.get('MeSH terms', []))

    return keywords, mesh_terms

def normalize_name(name):
    if "," in name:
        comma_index = name.find(",")
        return name[:comma_index]
    return name

def parse_ed_data():
    with open(ed_gpt_path, 'r') as gpt_file, open(ed_scraper_path, 'r') as scraper_file:
        gpt_data = json.load(gpt_file)
        scraper_data = json.load(scraper_file)

    gpt_dict = {}
    scraper_dict = {}
    for name in scraper_data:
        if len(scraper_data[name].split()) > 10:
            scraper_dict[normalize_name(name)] = scraper_data[name]


    for researcher in gpt_data:
        name = researcher["Name"]
        name = name.split(", ")
        name[0], name[-1] = name[-1], name[0]
        name = " ".join(name)
        name = normalize_name(name)
        content = researcher.get('DivConq', "")
        gpt_dict[name] = content

    with open('/content/DBMI_research_profile_crawler/yilu_results.json', 'r') as file:
        yilu_data = json.load(file)

    researcher_dict = {item['Name']: item['DivConq'] for item in yilu_data}
    for i in researcher_dict:
        if i not in gpt_dict:
            gpt_dict[i] = researcher_dict[i]

    return scraper_dict, gpt_dict
# def normalize_name(name):
#     # Remove titles like "PhD", "MD", etc.
#     name = re.sub(r',?\s*(PhD|MD|Dr|Prof|MS|mfa|ph.d|d.|mph|msw|mba|cgc|l|mbe|ma|otr/l|bcb|m.|llb|ch.b|gpd)\.?', '', name, flags=re.IGNORECASE)
#     # Remove middle names/initials
#     name = re.sub(r'\b[A-Z]\.\b', '', name)
#     # Remove extra whitespace and convert to lower case
#     name = re.sub(r'\s+', ' ', name).strip().lower()
#     return name

# function to get rid of the titles following after the name
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from tkinter import FALSE
comparison_names = {}
# read from the csv file and extract the researcher name with their research introduction scraped by the web scraper
with open(comparison_csv_path, mode='r', newline='', encoding='utf-8') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        if row['Research Introduction'] != 'N/A':
            comparison_names[row['Name']] = row['Research Introduction']
# scraped content
normalized_comparison_names = {normalize_name(name): intro for name, intro in comparison_names.items()}
# print(normalized_comparison_names.keys())
scraper_dict, gpt_dict = parse_ed_data()
# add Ed's data into the dictionary
for name in scraper_dict:
    found = False
    for i in normalized_comparison_names:
        if (name[0], name[-1]) == (i[0], i[-1]):
            found = True
            break
    if not found:
        capitalized_name = ""
        for i in range(len(name)):
            if i != 0 and name[i-1] == " ":
                capitalized_name += name[i].upper()
            elif i == 0:
                capitalized_name += name[i].upper()
            else:
                capitalized_name += name[i]
        normalized_comparison_names[capitalized_name] = scraper_dict[name]

# print(normalized_comparison_names)
#names extracted from the json file
file_names = []
# GPT summarized content based on Keywords and MeSH Terms
file_names_dict = {}
for filename in os.listdir(candidate_path):
    if filename.endswith('.txt'):
        name, _ = os.path.splitext(filename)
        # file_names.append(name.lower())
        file_names.append(name)
        # name = name.lower()
        name = name.split(" ")
        first_name, last_name = name[0], name[-1]
        file_names_dict[(first_name, last_name)] = filename
print(len(file_names))
for i in range(len(file_names)):
    name = file_names[i].split(" ")
    first_name, last_name = name[0], name[-1]
    file_names[i] = (first_name, last_name)

matches = {}
for i in normalized_comparison_names:
    name = i.split(" ")
    if (name[0], name[-1]) in file_names and normalized_comparison_names[i] != 'N/A':
        matches[i] = normalized_comparison_names[i]

def remove_last_sentence_if_link(paragraph):
    # Regular expression to match sentences
    sentence_endings = re.compile(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|\!)\s')

    # Regular expression to detect URLs
    url_pattern = re.compile(r'http[s]?://\S+')
    sentences = sentence_endings.split(paragraph.strip())

    last_sentence = sentences[-1]
    if url_pattern.search(last_sentence):
        sentences.pop()
    new_paragraph = ' '.join(sentences)
    return new_paragraph
for name in matches:
    matches[name] = remove_last_sentence_if_link(matches[name])
    # print(matches[name])
abstract_match = {} # gpt generated research summary
for i in gpt_dict:
    i_split = i.split(" ")
    for name in normalized_comparison_names:
        name_split = name.split(' ')
        if (i == name or (i_split[0] == name_split[0] and i_split[-1] == name_split[-1])) and normalized_comparison_names[name] != 'N/A':
            abstract_match[name] = gpt_dict[i]

print("Abstract based:", len(abstract_match))
print("MeSH Term based:", len(matches))


# print(dict(sorted(gpt_dict.items(), key=lambda item: item[0], reverse = True)).keys())
# print(dict(sorted(normalized_comparison_names.items(), key=lambda item: item[0], reverse = True)).keys())
# Out:
# 714
# Abstract based: 214
# MeSH Term based: 214

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

EXACT_MATCH_THRESHOLD = 1.0  # Exact match
APPROXIMATE_MATCH_THRESHOLD = 0.8  # Approximate match if similarity ratio >= 0.8

# List of excluded name pairs (ensure this list is symmetric)
excluded_pairs = [
    ('Jian Yang', 'Dian Yang'),
    ('Michael Shelanski', 'Michael Shen'),
    ('Peter Yim', 'Peter Sims'),
    ('Richard Friesner', 'Richard Friedman'),
    ('Xueling Wu', 'Xuebing Wu'),
    ('Andrew Yates', 'Andrew Kanter'),
    ('Michael Shadlen', 'Michael Shen'),
    ('Michael Shen', 'Michael Shadlen'),
    ('Richard Friedman', 'Richard Friesner'),
    ('Dian Yang', 'Jian Yang'),
    ('Michael Shen', 'Michael Shelanski'),
    ('Peter Sims', 'Peter Yim'),
    ('Xuebing Wu', 'Xueling Wu'),
    ('Andrew Kanter', 'Andrew Yates')
]

# Convert excluded_pairs to a set of frozensets for easier comparison
excluded_pairs_set = {frozenset(pair) for pair in excluded_pairs}

# Counters
exact_matches = 0
approximate_matches = 0

# Lists to store matching names
exact_match_names = []
approximate_match_names = []
names_in_matches_not_in_gpt_dict = []
total_match_name = set()

# Compare names in the dictionaries
for name1 in matches:
    for name2 in gpt_dict:
        similarity_score = similar(name1, name2)

        if frozenset([name1, name2]) in excluded_pairs_set:
            continue  # Skip excluded pairs

        if similarity_score >= EXACT_MATCH_THRESHOLD:
            exact_matches += 1
            exact_match_names.append((name1, name2))
            total_match_name.add(name1)
            break

        elif similarity_score >= APPROXIMATE_MATCH_THRESHOLD:
            approximate_matches += 1
            approximate_match_names.append((name1, name2))
            total_match_name.add(name1)
            break

# Find names in 'matches' not in 'gpt_dict'
counter = 0
for name in matches:
    if name not in total_match_name:
        print(name)
        counter += 1

print("=================")
for pairs in excluded_pairs:
    if pairs[0] in total_match_name or pairs[1] in total_match_name:
        print("Match: ", pairs)

print(f"Total names in matches: {len(matches)}")
print(f"Names not matched: {counter}")
print(f"Total matched names: {len(total_match_name)}")

# Display the results
print(f"Exact Matches: {exact_matches}")
print("Exact Match Names:")
for pair in exact_match_names:
    print(f"  {pair[0]} == {pair[1]}")

print(f"\nApproximate Matches: {approximate_matches}")
print("Approximate Match Names:")
for pair in approximate_match_names:
    print(f"  {pair[0]} ~ {pair[1]}")
# Out:
# =================
# Match:  ('Jian Yang', 'Dian Yang')
# Match:  ('Michael Shelanski', 'Michael Shen')
# Match:  ('Peter Yim', 'Peter Sims')
# Match:  ('Richard Friesner', 'Richard Friedman')
# Match:  ('Xueling Wu', 'Xuebing Wu')
# Match:  ('Andrew Yates', 'Andrew Kanter')
# Match:  ('Michael Shadlen', 'Michael Shen')
# Match:  ('Michael Shen', 'Michael Shadlen')
# Match:  ('Richard Friedman', 'Richard Friesner')
# Match:  ('Dian Yang', 'Jian Yang')
# Match:  ('Michael Shen', 'Michael Shelanski')
# Match:  ('Peter Sims', 'Peter Yim')
# Match:  ('Xuebing Wu', 'Xueling Wu')
# Match:  ('Andrew Kanter', 'Andrew Yates')
# Total names in matches: 214
# Names not matched: 0
# Total matched names: 214
# Exact Matches: 173
# Exact Match Names:
#   Richard Axel == Richard Axel
#   Bridget Carragher == Bridget Carragher
#   Anum Glasgow == Anum Glasgow
#   Oliver Hobert == Oliver Hobert
#   Eric Kandel == Eric Kandel
#   Arthur Karlin == Arthur Karlin
#   Laura Landweber == Laura Landweber
#   Michal Levo == Michal Levo
#   Stavros Lomvardas == Stavros Lomvardas
#   Tom Maniatis == Tom Maniatis
#   Richard S. Mann == Richard S. Mann
#   David E. Shaw == David E. Shaw
#   Alexander Sobolevsky == Alexander Sobolevsky
#   Anna-Lena Steckelberg == Anna-Lena Steckelberg
#   Samuel Sternberg == Samuel Sternberg
#   Chaolin Zhang == Chaolin Zhang
#   Charles Zuker == Charles Zuker
#   Philippe J. Batut == Philippe J. Batut
#   Amanda L. Bergner == Amanda L. Bergner
#   Timothy H. Bestor == Timothy H. Bestor
#   Chia-Wei Cheng == Chia-Wei Cheng
#   Angela Christiano == Angela Christiano
#   Riccardo Dalla-Favera == Riccardo Dalla-Favera
#   Wayne Frankel == Wayne Frankel
#   Jean Gautier == Jean Gautier
#   Vincenzo Alessandro Gennarino == Vincenzo Alessandro Gennarino
#   Chao Lu == Chao Lu
#   Eric A. Schon == Eric A. Schon
#   Mimi Shirasu-Hiza == Mimi Shirasu-Hiza
#   Mijo Simunovic == Mijo Simunovic
#   Gary Struhl == Gary Struhl
#   Andrew Tomlinson == Andrew Tomlinson
#   Debra J Wolgemuth == Debra J Wolgemuth
#   Kelley Yan == Kelley Yan
#   Zhiguo Zhang == Zhiguo Zhang
#   Rita Charon == Rita Charon
#   Maya Sabatello == Maya Sabatello
#   Alexis Walker == Alexis Walker
#   Caitlin McMahon == Caitlin McMahon
#   David Lamb == David Lamb
#   Rachel Yarmolinsky == Rachel Yarmolinsky
#   Jordana Vanderselt == Jordana Vanderselt
#   Cindy Smalletz == Cindy Smalletz
#   Sandra Soo-Jin Lee == Sandra Soo-Jin Lee
#   Nicholas Arpaia == Nicholas Arpaia
#   Uttiya Basu == Uttiya Basu
#   Hachung Chung == Hachung Chung
#   Lei Ding == Lei Ding
#   Donna Farber == Donna Farber
#   Sankar Ghosh == Sankar Ghosh
#   Arnold Han == Arnold Han
#   Yuefeng Huang == Yuefeng Huang
#   Ivaylo Ivanov == Ivaylo Ivanov
#   Hans-Willem Snoeck == Hans-Willem Snoeck
#   Megan Sykes == Megan Sykes
#   Shan Zha == Shan Zha
#   Jonathan Dworkin == Jonathan Dworkin
#   Chi-Min Ho == Chi-Min Ho
#   Anne Moscona == Anne Moscona
#   Vincent Racaniello == Vincent Racaniello
#   Cory Abate-Shen == Cory Abate-Shen
#   Henry Colecraft == Henry Colecraft
#   Concepcion CP == Concepcion CP
#   Sabrina Diano == Sabrina Diano
#   Jonathan A. Javitch == Jonathan A. Javitch
#   Christoph Kellendonk == Christoph Kellendonk
#   Steven A. Siegelbaum == Steven A. Siegelbaum
#   David Sulzer == David Sulzer
#   Shi Du Yan == Shi Du Yan
#   Dian Yang == Dian Yang
#   Yonghao Yu == Yonghao Yu
#   Larry Abbott == Larry Abbott
#   Dmitriy Aronov == Dmitriy Aronov
#   Rudy Behnia == Rudy Behnia
#   Mark Churchland == Mark Churchland
#   Rui M. Costa == Rui M. Costa
#   Aniruddha Das == Aniruddha Das
#   Jane Dodd == Jane Dodd
#   Yasmine El-Shamayleh == Yasmine El-Shamayleh
#   Vincent P. Ferrera == Vincent P. Ferrera
#   Stefano Fusi == Stefano Fusi
#   Vikram Gadagkar == Vikram Gadagkar
#   Joseph A. Gogos == Joseph A. Gogos
#   Jacqueline Gottlieb == Jacqueline Gottlieb
#   Wesley Grueber == Wesley Grueber
#   Robert D. Hawkins == Robert D. Hawkins
#   Elias Issa == Elias Issa
#   Itamar Kahn == Itamar Kahn
#   Minoree Kohwi == Minoree Kohwi
#   Nikolaus Kriegeskorte == Nikolaus Kriegeskorte
#   Attila Losonczy == Attila Losonczy
#   Kenneth Miller == Kenneth Miller
#   Liam Paninski == Liam Paninski
#   Serge Przedborski == Serge Przedborski
#   Ning Qian == Ning Qian
#   Nathaniel Sawtell == Nathaniel Sawtell
#   Michael Shadlen == Michael Shadlen
#   Clarissa Waites == Clarissa Waites
#   Hynek Wichterle == Hynek Wichterle
#   Jahar Bhattacharya == Jahar Bhattacharya
#   Laurence F. Abbott == Laurence F. Abbott
#   Qais Al-Awqati == Qais Al-Awqati
#   Oliver Clarke == Oliver Clarke
#   Wayne Hendrickson == Wayne Hendrickson
#   Stavroula Kousteni == Stavroula Kousteni
#   X. Shawn Liu == X. Shawn Liu
#   Filippo Mancia == Filippo Mancia
#   Matthias Quick == Matthias Quick
#   Samuel Silverstein == Samuel Silverstein
#   Tannishtha Reya == Tannishtha Reya
#   Ira Tabas == Ira Tabas
#   Yvon Woappi == Yvon Woappi
#   David Knowles == David Knowles
#   Jeremy Worley == Jeremy Worley
#   Yufeng Shen == Yufeng Shen
#   Kam Leong == Kam Leong
#   Itsik Pe'er == Itsik Pe'er
#   Andrea Califano == Andrea Califano
#   Aris Floratos == Aris Floratos
#   Saeed Tavazoie == Saeed Tavazoie
#   Milan Stojanovic == Milan Stojanovic
#   Gustavo Stolovitzky == Gustavo Stolovitzky
#   Dennis Vitkup == Dennis Vitkup
#   Michael Shen == Michael Shen
#   Barry Honig == Barry Honig
#   Virginia Cornish == Virginia Cornish
#   Harris Wang == Harris Wang
#   Xuebing Wu == Xuebing Wu
#   Sara Zaccara == Sara Zaccara
#   Peter Sims == Peter Sims
#   Benjamin Izar == Benjamin Izar
#   Mikko Turunen == Mikko Turunen
#   Harmen Bussemaker == Harmen Bussemaker
#   Tuuli Lappalainen == Tuuli Lappalainen
#   Molly Przeworski == Molly Przeworski
#   Dimitris Anastassiou == Dimitris Anastassiou
#   Raul Rabadan == Raul Rabadan
#   Mohammed AlQuraishi == Mohammed AlQuraishi
#   Tal Korem == Tal Korem
#   Jason Adelman == Jason Adelman
#   David Albers == David Albers
#   Amelia Averitt == Amelia Averitt
#   Suzanne Bakken == Suzanne Bakken
#   Herbert Chase == Herbert Chase
#   James Cimino == James Cimino
#   Paul Clayton == Paul Clayton
#   Timothy J. Crimmins == Timothy J. Crimmins
#   Pierre Elias == Pierre Elias
#   Bruce Forman == Bruce Forman
#   Carol Friedman == Carol Friedman
#   Richard Friedman == Richard Friedman
#   Christopher Haggerty == Christopher Haggerty
#   George Hripcsak == George Hripcsak
#   Shalmali Joshi == Shalmali Joshi
#   Andrew Kanter == Andrew Kanter
#   Despina Kontos == Despina Kontos
#   Rita Kukafka == Rita Kukafka
#   Gilad Kuperman == Gilad Kuperman
#   Matthew Mcdermott == Matthew Mcdermott
#   Karthik Natarajan == Karthik Natarajan
#   Soojin Park == Soojin Park
#   Vimla Patel == Vimla Patel
#   Adler Perotte == Adler Perotte
#   Rimma Perotte == Rimma Perotte
#   Lauren Richter == Lauren Richter
#   Sarah Collins Rossetti == Sarah Collins Rossetti
#   Patrick Ryan == Patrick Ryan
#   Soumitra Sengupta == Soumitra Sengupta
#   Edward H. (ted) Shortliffe == Edward H. (ted) Shortliffe
#   Nicholas Tatonetti == Nicholas Tatonetti
#   David Vawdrey == David Vawdrey
#   Chunhua Weng == Chunhua Weng
#   Xuhai Xu == Xuhai Xu
#
# Approximate Matches: 41
# Approximate Match Names:
#   Hashim M. Al-Hashimi ~ Hashim Al-Hashimi
#   Stephen P. Goff ~ Stephen Goff
#   Max E. Gottesman ~ Max E Gottesman
#   Eric C.  Greene ~ Eric Greene
#   Iva S. Greenwald ~ Iva Greenwald
#   Peter D. Kwong ~ Peter Kwong
#   Lawrence S. Shapiro ~ Lawrence Shapiro
#   Peter A. Sims ~ Peter Sims
#   Luke E. Berchowitz ~ Luke Berchowitz
#   Wellington V. Cardoso ~ Wellington Cardoso
#   Frank Costantini ~ Franklin Costantini
#   Laura A. Johnston ~ Laura Johnston
#   Cathy Mendelsohn ~ Cathy Lee Mendelsohn
#   Emmanuelle Passegué ~ Emmanuelle Passegue
#   Rodney Rothstein ~ Rodney Joel Rothstein
#   Lorraine S. Symington ~ Lorraine Symington
#   Aaron D Viny ~ Aaron Viny
#   David A. Fidock ~ David Fidock
#   Yiping W. Han ~ Yiping Han
#   David D. Ho ~ David Ho
#   Qing R. Fan ~ Qing Fan
#   Neil L. Harrison ~ Neil Harrison
#   Robert S. Kass ~ Robert Kass
#   Steven Owen Marx ~ Steven Marx
#   Susan F. Steinberg ~ Susan F Steinberg
#   Michael Ellis Goldberg ~ Michael Goldberg
#   Carol A. Mason ~ Carol Ann Mason
#   Kapil V. Ramachandran ~ Kapil Ramachandran
#   Daniel Salzman ~ C. Daniel Salzman
#   Daniel M. Wolpert ~ Daniel Wolpert
#   Manu Ben-Johny ~ Manu Johny
#   Joseph Gogos ~ Joseph A. Gogos
#   Jonathan Javitch ~ Jonathan A. Javitch
#   Andrew R. Marks ~ Andrew Marks
#   Richard Mann ~ Richard S. Mann
#   Noémie Elhadad ~ Noemie Elhadad
#   Aristidis Floratos ~ Aris Floratos
#   Gamze Gürsoy ~ Gamze Gursoy
#   Virginia Lorenzi ~ Virginia Cornish
#   Lena Mamykina ~ Olena Mamykina
#   Steven Shea ~ Steven J Shea

# %% [markdown]
# # **GPT Text Quality Evaluation**

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.42.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Downloading openai-1.42.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.9/362.9 kB 20.3 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.3 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 27.6 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jiter-0.5.0 openai-1.42.0

# %%
from openai import OpenAI
for test_name in matches:
    test_name_copy = test_name
    test_name = test_name.split(" ")
    test_first_name, test_last_name = test_name[0], test_name[-1]
    test_path = candidate_path + '/' + file_names_dict[(test_first_name, test_last_name)]

    with open(test_path, 'r', encoding='utf-8') as file:
        test_contents = file.read()

    # Tokenize the paragraphs into sentences
    # reference_sentences = nltk.sent_tokenize(matches[test_name_copy])
    # candidate_sentences = nltk.sent_tokenize(test_contents)
    GPT_API_KEY = ''
    client = OpenAI(api_key=GPT_API_KEY)
    response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
              {"role": "system",
               "content": "You are a helpful Researcher Profile Summarization Quality evaluator."},
              {"role": "user", "content": f"""Based on the given evaluation metrics and the gold truth of the researcher's research overview as a reference, evaluate the research overview about a researcher given below.
Evluation Metrics: (CONTENT) Grade the research overview tp be evaluated on a scale of 1 to 10 for how well it represents the researcher. Rate:
Excellent Profile Description (8.1-10.0): The profile provides a comprehensive and compelling overview of the researcher’s work. It clearly highlights the significance, originality, and impact of their research. The description is well-organized, engaging, and includes specific achievements, methodologies, and outcomes. It effectively communicates the researcher’s expertise and contributions to the field.
Good Profile Description (6.1-8.0): The profile gives a clear and informative summary of the researcher’s work. It includes relevant details about their research focus, methodologies, and contributions. While the description is solid and informative, it may lack some depth or clarity in certain areas. It qualifies as a strong representation of the researcher’s achievements and expertise.
Fair Profile Description (4.1-6.0): The profile provides a basic overview of the researcher’s work but lacks detail or clarity in some aspects. It may include general information about the research focus but lacks specific examples or a clear explanation of the impact and significance. The description is sufficient for basic understanding but does not effectively highlight the researcher’s unique contributions or achievements.
Poor Profile Description (2.1-4.0): The profile provides minimal information about the researcher’s work. It lacks detail, specificity, and clarity, making it difficult to understand the research focus or its significance. The description may be too vague or incomplete, failing to convey the researcher’s contributions effectively.
Inadequate Profile Description (0.0-2.0): The profile does not provide meaningful information about the researcher’s work. It is either extremely vague, misleading, or irrelevant, with little to no useful content about the researcher’s contributions or achievements. The description fails to communicate the research focus and is not helpful for understanding the researcher’s expertise.

(QUALITY) Judge the research overview to be evaluated on a 10 point scale (1 being poor, 10 being great) for coherence, factual consistency, comprehensiveness, and harmfulness/misrepresentation. For each abstract, rate
Coherence (10): The Research Overview to be evaluated is exceptionally clear and logically organized. It presents information in a seamless, engaging manner, making it easy to grasp the research focus and its significance.
Consistency (10): Consistency indicates whether the research overview to be evaluated contradicts the Gold Truth.
Comprehensive (10): Comprehensiveness measures the coverage, of research overview to be evlauted, of key information of Gold Truth.
Specificity (10): Specificity measures the preciseness and conciseness of the research voerview to be evaluated.
Readability (10): Readability indicates whether the Researc Overview to be evaluated is fluent and free of grammatical errors that hinder understanding.
Relevance (10): Relevance measures how pertinent or appropriate the information included in the Research Overview to be evaluated is concerning the Gold Truth

Gold Truth: {matches[test_name_copy]}

Research Overview to be evaluated: {test_contents}
"""
              }


            ]
        )
    content = response.choices[0].message.content
    print(content)
    break
# Out:
# **Evaluation of Research Overview for Hashim M. Al-Hashimi**
#
# **CONTENT Evaluation (Scale 1 to 10):**
# Grade: **6.5**
#
# **Justification:**
# The research overview provides a clear and informative summary of the researcher’s focus on nucleic acids and their dynamics. It covers several relevant areas, including DNA repair mechanisms, conformational dynamics, and the impact of chemical modifications. However, it lacks some depth and specific examples that highlight the original contributions and methodologies employed by Al-Hashimi. It doesn't adequately address the broad range of applications mentioned in the Gold Truth, such as the reconstitution of RNA folding or high throughput approaches to study DNA structural dynamics. Overall, while it is a solid representation, it could benefit from clearer organization and more detailed examples of findings and implications in the field.
#
# ---
#
# **QUALITY Evaluation (Scale 1 to 10):**
#
# - **Coherence:** **8**
#   - The overview is generally well-organized and presents information in a logical manner, but there are minor areas where clarity could be improved.
#
# - **Consistency:** **7**
#   - The overview mostly aligns with the Gold Truth but introduces slight inconsistencies when discussing the scope and impact of Al-Hashimi's work, particularly regarding current research directions that are mentioned in the Gold Truth.
#
# - **Comprehensive:** **6**
#   - The overview covers key aspects of Al-Hashimi's research; however, it misses several key themes and specific methodologies mentioned in the Gold Truth description. It does not sufficiently address the comprehensive use of multiple techniques combined, as highlighted in the Gold Truth.
#
# - **Specificity:** **6**
#   - The overview includes some specifics about techniques (e.g., NMR spectroscopy) but lacks precise examples of the quantitative models or specific findings of his research as outlined in the Gold Truth.
#
# - **Readability:** **9**
#   - The writing is fluent, and there are no significant grammatical errors that hinder understanding, making it easy to read and follow.
#
# - **Relevance:** **7**
#   - Most of the information is relevant to Al-Hashimi's research, but some aspects could be more focused on the highlighted broader impacts and current research themes noted in the Gold Truth, which are crucial for relevant context.
#
# ---
#
# **Overall Summary:**
# The research overview of Hashim M. Al-Hashimi presents a respectable summary of his work but could be enhanced by incorporating more specific examples and in-depth insights into his contributions as presented in the Gold Truth. The coherence and readability of the overview are solid, but additional detail and alignment with the Gold Truth will elevate its overall impact and representation of the researcher’s prowess in the field.

# %% [markdown]
# # **BLEU, ROUGE, and METEOR MeSH & Keywords**

# %%
average_bleu_score_for_researchers = 0
average_rouge1_score_for_researchers = 0
average_rouge2_score_for_researchers = 0
average_rougeL_score_for_researchers = 0
average_meteor_score_for_researchers = 0
for test_name in matches:
    test_name_copy = test_name
    test_name = test_name.split(" ")
    test_first_name, test_last_name = test_name[0], test_name[-1]
    test_path = candidate_path + '/' + file_names_dict[(test_first_name, test_last_name)]
    with open(test_path, 'r', encoding='utf-8') as file:
        test_contents = file.read()
    if average_bleu_score_for_researchers == 0:
        print(matches[test_name_copy])
        print(test_contents)
    # Tokenize the paragraphs into sentences
    reference_sentences = nltk.sent_tokenize(matches[test_name_copy])
    candidate_sentences = nltk.sent_tokenize(test_contents)

    # Tokenize sentences into words for BLEU and METEOR
    reference_tokens = [nltk.word_tokenize(sentence) for sentence in reference_sentences]
    candidate_tokens = [nltk.word_tokenize(sentence) for sentence in candidate_sentences]

    # BLEU Score Calculation
    bleu_scores = []
    for reference, candidate in zip(reference_tokens, candidate_tokens):
        score = sentence_bleu([reference], candidate)
        bleu_scores.append(score)

    average_bleu_score = sum(bleu_scores) / len(bleu_scores)
    # print(f"Average BLEU score for {test_name_copy}: {average_bleu_score}")
    average_bleu_score_for_researchers += average_bleu_score

    # ROUGE Score Calculation
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge_scores = []
    for reference, candidate in zip(reference_sentences, candidate_sentences):
        scores = scorer.score(reference, candidate)
        rouge_scores.append(scores)

    average_rouge1 = sum([score['rouge1'].fmeasure for score in rouge_scores]) / len(rouge_scores)
    average_rouge2 = sum([score['rouge2'].fmeasure for score in rouge_scores]) / len(rouge_scores)
    average_rougeL = sum([score['rougeL'].fmeasure for score in rouge_scores]) / len(rouge_scores)
    # print(f"ROUGE Score for {test_name_copy}:")
    # print(f"Average ROUGE-1 score: {average_rouge1:.2f}")
    # print(f"Average ROUGE-2 score: {average_rouge2:.2f}")
    # print(f"Average ROUGE-L score: {average_rougeL:.2f}")
    average_rouge1_score_for_researchers += average_rouge1
    average_rouge2_score_for_researchers += average_rouge2
    average_rougeL_score_for_researchers += average_rougeL

    meteor_scores = []
    for reference, candidate in zip(reference_sentences, candidate_sentences):
        reference_tokens = nltk.word_tokenize(reference)
        candidate_tokens = nltk.word_tokenize(candidate)
        score = meteor_score([reference_tokens], candidate_tokens)
        meteor_scores.append(score)

    average_meteor_score = sum(meteor_scores) / len(meteor_scores) if meteor_scores else 0
    # print(f"METEOR Score for {test_name_copy}: {average_meteor_score:.2f}")
    average_meteor_score_for_researchers += average_meteor_score
average_bleu_score_for_researchers /= len(matches)
average_rouge1_score_for_researchers /= len(matches)
average_rouge2_score_for_researchers /= len(matches)
average_rougeL_score_for_researchers /= len(matches)
average_meteor_score_for_researchers /= len(matches)
print(f"Average BLEU Score for all researchers: {average_bleu_score_for_researchers}")
print(f"Average ROUGE1 Score for all researchers: {average_rouge1_score_for_researchers}")
print(f"Average ROUGE2 Score for all researchers: {average_rouge2_score_for_researchers}")
print(f"Average ROUGEL Score for all researchers: {average_rougeL_score_for_researchers}")
print(f"Average METEOR Score for all researchers: {average_meteor_score_for_researchers}")
# Out:
# Al-Hashimi is interested in developing a deep, quantitative, and predictive understanding of cellular processes based on the fundamental behaviors of nucleic acids and their interactions with protein binding partners.  Over the past two decades, Al-Hashimi and his trainees developed approaches combining NMR spectroscopy, computational modeling, optical melting experiments, and chemical probing to determine 3D dynamic ensembles of RNA and DNA molecules at atomic resolution.  Using dynamic ensembles of nucleic acids, the Al-Hashimi group has developed quantitative and predictive models for several fundamental biological processes, including DNA replication fidelity, Tat-dependent HIV-1 transcriptional activation, RNA folding, and the impact of post-transcriptional modifications such as m6A and Nm on translation, splicing, and RNA-protein interactions.  These studies have reshaped structural biology, revealing dynamic ensembles as the fundamental behavior of biomolecules needed to understand and predict cellular activity quantitatively.The Al-Hashimi lab is currently using dynamic ensembles to reconstitute the folding and cellular activities of viral and other non-coding RNAs, to determine the role of DNA structural dynamics in shaping the probabilities of mutagenesis and cancer, and to rationally design inhibitors targeting viral RNA regulatory elements in HIV-1 and SARS-CoV-2 as well as non-coding RNAs involved in cancer.  Efforts include developing and applying high throughput sequencing-based approaches to map DNA structural dynamics genome-wide, developing high throughput assays for quantitatively measuring the activity of various steps in the HIV-1 lifecycle, and determining an atlas of dynamic ensembles for all nucleic acid building block motifs.  A more recent area includes efforts to digitize biochemistry by describing biomolecules in terms of finite-state-computing machines and applying complexity theory to classifying biochemical reactions.As a mentor, Al-Hashimi is strongly committed to creating a welcoming, enriching, and supportive environment for all his trainees and effectively preparing them for careers in science.  To date, he has trained over thirty-five graduate students and postdoctoral fellows with backgrounds in biochemistry, cell biology, chemistry, computer science, physics, and mathematics.  His alumni include heads of laboratories at universities in the US, France, Sweden, India, and China and scientists at many biotech companies, large pharmaceutical firms, and management consulting firms.
# Researcher: Hashim M. Al-Hashimi
# Research Overview:
# Hashim M. Al-Hashimi's research primarily focuses on the intricate dynamics of nucleic acids, especially in relation to DNA damage and the recognition mechanisms involved in biological computation and mutation processes. His work delves into areas like conformational dynamics of DNA and RNA, exploring the implications of DNA repair mechanisms, replication errors, and the impact of chemical modifications such as methylation. Using techniques such as solid-state and solution-state NMR spectroscopy, he examines the behaviors of various nucleobases including guanine and adenine in polymorphic states, contributing to a deeper understanding of biophysical phenomena. His investigations into the interaction of RNA with ligands and its flexibility further advance the field of RNA-targeted drug discovery, particularly concerning HIV-1. Overall, his research aims to elucidate the fundamental biophysical properties of nucleic acids, with significant implications for molecular biology, epitranscriptomics, and therapeutic development.
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Average BLEU Score for all researchers: 0.0011713175537968587
# Average ROUGE1 Score for all researchers: 0.1658672702747221
# Average ROUGE2 Score for all researchers: 0.015090629086747466
# Average ROUGEL Score for all researchers: 0.12603716191097858
# Average METEOR Score for all researchers: 0.1331699616830043

# %% [markdown]
# # **BLEU, ROUGE and METEOR Abstract**

# %%
average_bleu_score_for_researchers = 0
average_rouge1_score_for_researchers = 0
average_rouge2_score_for_researchers = 0
average_rougeL_score_for_researchers = 0
average_meteor_score_for_researchers = 0
for test_name in abstract_match:
    test_contents = abstract_match[test_name]
    if average_bleu_score_for_researchers == 0:
        print(test_name)
        print(matches[test_name])
        print(test_contents)
    # Tokenize the paragraphs into sentences
    reference_sentences = nltk.sent_tokenize(normalized_comparison_names[test_name])
    candidate_sentences = nltk.sent_tokenize(test_contents)

    # Tokenize sentences into words for BLEU and METEOR
    reference_tokens = [nltk.word_tokenize(sentence) for sentence in reference_sentences]
    candidate_tokens = [nltk.word_tokenize(sentence) for sentence in candidate_sentences]

    # BLEU Score Calculation
    bleu_scores = []
    for reference, candidate in zip(reference_tokens, candidate_tokens):
        score = sentence_bleu([reference], candidate)
        bleu_scores.append(score)

    average_bleu_score = sum(bleu_scores) / len(bleu_scores)
    # print(f"Average BLEU score for {test_name_copy}: {average_bleu_score}")
    average_bleu_score_for_researchers += average_bleu_score

    # ROUGE Score Calculation
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge_scores = []
    for reference, candidate in zip(reference_sentences, candidate_sentences):
        scores = scorer.score(reference, candidate)
        rouge_scores.append(scores)

    average_rouge1 = sum([score['rouge1'].fmeasure for score in rouge_scores]) / len(rouge_scores)
    average_rouge2 = sum([score['rouge2'].fmeasure for score in rouge_scores]) / len(rouge_scores)
    average_rougeL = sum([score['rougeL'].fmeasure for score in rouge_scores]) / len(rouge_scores)
    # print(f"ROUGE Score for {test_name_copy}:")
    # print(f"Average ROUGE-1 score: {average_rouge1:.2f}")
    # print(f"Average ROUGE-2 score: {average_rouge2:.2f}")
    # print(f"Average ROUGE-L score: {average_rougeL:.2f}")
    average_rouge1_score_for_researchers += average_rouge1
    average_rouge2_score_for_researchers += average_rouge2
    average_rougeL_score_for_researchers += average_rougeL

    meteor_scores = []
    for reference, candidate in zip(reference_sentences, candidate_sentences):
        reference_tokens = nltk.word_tokenize(reference)
        candidate_tokens = nltk.word_tokenize(candidate)
        score = meteor_score([reference_tokens], candidate_tokens)
        meteor_scores.append(score)

    average_meteor_score = sum(meteor_scores) / len(meteor_scores) if meteor_scores else 0
    # print(f"METEOR Score for {test_name_copy}: {average_meteor_score:.2f}")
    average_meteor_score_for_researchers += average_meteor_score
average_bleu_score_for_researchers /= len(abstract_match)
average_rouge1_score_for_researchers /= len(abstract_match)
average_rouge2_score_for_researchers /= len(abstract_match)
average_rougeL_score_for_researchers /= len(abstract_match)
average_meteor_score_for_researchers /= len(abstract_match)
print(f"Average BLEU Score for all researchers: {average_bleu_score_for_researchers}")
print(f"Average ROUGE1 Score for all researchers: {average_rouge1_score_for_researchers}")
print(f"Average ROUGE2 Score for all researchers: {average_rouge2_score_for_researchers}")
print(f"Average ROUGEL Score for all researchers: {average_rougeL_score_for_researchers}")
print(f"Average METEOR Score for all researchers: {average_meteor_score_for_researchers}")
# Out:
# Christoph Kellendonk
# The Kellendonk laboratory uses circuit dissection tools in the mouse to understand the biology that underlies cognitive, negative and positive symptoms of schizophrenia. To this end we have been manipulating the expression levels of dopamine D2 receptors and neuronal activity in genetically defined sub-circuits of the striatum and studied the consequences of these manipulations on behavior and circuit function. Using similar approaches, we have been studying the role of thalamo-prefrontal circuits in cognition and working memory. Recently, we began to address the role of dopamine in the generation of false percepts which has relevance to auditory hallucinations in humans.
# This researcher's research directions can be categorized into the following atomic topics and fields: thalamocortical projections, prefrontal cortex function, cognitive deficits, chemogenetics, organoid studies, synaptic dynamics, serotonin signaling, maternal health and schizophrenia, basal ganglia circuitry, dopamine signaling, cholinergic interneurons, and neuropsychiatric disorders. The research on thalamocortical projections focuses on how inhibition during adolescence affects long-term prefrontal cortex (PFC) function and cognition, revealing that thalamic activity is crucial for PFC maturation. This work utilizes chemogenetic tools to manipulate thalamic inputs and assess their impact on synaptic currents in prefrontal pyramidal neurons, demonstrating altered excitation-inhibition balance and highlighting the importance of intra-prefrontal inhibitory connectivity for circuit maturation. The study of cognitive deficits associated with thalamic inhibition during adolescence connects to broader implications for schizophrenia, where thalamic dysfunction may lead to persistent cognitive impairments. In organoid studies, researchers investigate the effects of a CNTNAP2 mutation linked to autism spectrum disorder (ASD), finding increased organoid volume and cell proliferation that can be corrected through CRISPR-Cas9, suggesting potential pathways for understanding ASD. The examination of synaptic dynamics in the medial prefrontal cortex (mPFC) reveals distinct input characteristics from the mediodorsal thalamus and ventral hippocampus, with implications for understanding how these regions integrate information. Serotonin signaling through 5-HT1A receptors during adolescence is also explored, indicating its role in mood regulation and potential links to depression-like phenotypes. Maternal health research connects C-reactive protein levels to schizophrenia risk, while studies on the mediodorsal thalamus highlight its role in cognitive flexibility and learning tasks. In the basal ganglia circuitry, the research emphasizes the significance of direct pathway striatal projection neurons (dSPNs) and their axon collaterals, which are crucial for motor control and have been previously overlooked. Dopamine signaling, particularly through D2 receptors, is investigated in relation to learning and motivation, with findings showing that D2 receptor dynamics influence cholinergic interneuron function and behavioral responses. This includes studies demonstrating the role of D2 receptors in sequence learning and motivation, as well as their complex interactions with dopamine and acetylcholine levels during cue responses. The multifaceted roles of D2 receptors are further explored in the context of neuropsychiatric disorders, such as schizophrenia, where alterations in D2 receptor levels affect motivation and behavior, suggesting significant implications for treatment strategies. Overall, this research spans a wide range of topics, each contributing to a deeper understanding of neural circuitry, cognitive function, and the biological underpinnings of psychiatric conditions.
# Average BLEU Score for all researchers: 0.0007186771734015823
# Average ROUGE1 Score for all researchers: 0.1419522354792272
# Average ROUGE2 Score for all researchers: 0.009046542078643286
# Average ROUGEL Score for all researchers: 0.10561531162634509
# Average METEOR Score for all researchers: 0.11695426487931017

# %% [markdown]
# # **Rhetorical Strucutre Theory**

# %% [markdown]
# # **Part-of-speech Tagging**

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 114.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
def pos_distribution(doc):
    '''
    This function counts the occurrences of each PoS tag in the document and returns a
    dictionary where the keys are the PoS tags and the values are their respective counts.
    '''
    pos_counts = doc.count_by(spacy.attrs.POS)
    return {doc.vocab[k].text: v for k, v in pos_counts.items()}

def lexical_diversity_by_pos(doc):
    '''
    This function creates a dictionary where each key is a PoS tag, and the value is the
    number of unique words (lexical diversity) associated with that tag in the document.
    '''
    pos_words = {}
    for token in doc:
        pos = token.pos_
        if pos not in pos_words:
            pos_words[pos] = set()
        pos_words[pos].add(token.text)
    return {pos: len(words) for pos, words in pos_words.items()}

def dependency_tree_depth(doc):
    '''
    The depth of the dependency tree is determined by the longest path from any token
    to the root of the sentence. This function finds the maximum depth among all tokens
    in the document.
    '''
    return max([len(list(token.ancestors)) for token in doc])

def head_dependent_pairs(doc):
    '''
    This function identifies the syntactic relationships between words by returning a list
    of tuples where each tuple consists of a head word and its dependent word.
    '''
    return [(token.head.text, token.text) for token in doc if token.head != token]

def modifiers_analysis(doc):
    '''
    This function identifies modifiers (adjectives and adverbs) in the document and
    returns a list of tuples where each tuple contains the head word, the modifier,
    and the type of modification (adjectival or adverbial).
    '''
    modifiers = []
    for token in doc:
        if token.dep_ in ['amod', 'advmod']:
            modifiers.append((token.head.text, token.text, token.dep_))
    return modifiers

def syntactic_complexity(doc):
    '''
    Syntactic complexity is measured by averaging the length of dependency paths (the depth
    of the tree) for all tokens in the document. This gives an indication of how complex
    the sentence structures are.
    '''
    return sum(len(list(token.ancestors)) for token in doc) / len(doc)


def syntactic_ambiguity(doc):
    """
    Identify potential syntactic ambiguities in the document.
    Ambiguity is flagged if a token has multiple potential heads or ambiguous modifiers.
    """
    ambiguities = []

    for token in doc:
        if len(list(token.children)) > 1:
            # Checking for ambiguity in modifiers
            modifiers = [child for child in token.children if child.dep_ in ['amod', 'advmod']]
            if len(modifiers) > 1:
                ambiguities.append((token.text, "Ambiguous Modifiers", [mod.text for mod in modifiers]))

        # Ambiguity in conjunctions (coordinating conjunctions)
        if token.dep_ == 'cc' and token.head.dep_ in ['conj']:
            ambiguities.append((token.text, "Ambiguous Conjunction", token.head.text))

    return ambiguities

# %% [markdown]
# # **MeSH Terms and Keywords**

# %%
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

total_human_written_tree_depth = 0
total_gpt_generated_tree_depth = 0
total_gpt_abstract_tree_depth = 0

total_human_written_complexity = 0
total_gpt_generated_complexity = 0
total_gpt_abstract_complexity = 0

total_human_written_ambiguities = 0
total_gpt_generated_ambiguities = 0
total_gpt_abstract_ambiguities = 0

total_pos_dist_human = {}
total_pos_dist_gpt = {}
total_pos_dist_abstract = {}

total_lexi_diver_human = {}
total_lexi_diver_gpt = {}
total_lexi_diver_abstract = {}

total_tests = len(matches)

for test_name in matches:
    print(f"Processing {test_name}")
    abstract_content = abstract_match[test_name]
    test_name_copy = test_name
    test_name = test_name.split(" ")
    test_first_name, test_last_name = test_name[0], test_name[-1]
    test_path = candidate_path + '/' + file_names_dict[(test_first_name, test_last_name)]

    with open(test_path, 'r', encoding='utf-8') as file:
        test_contents = file.read()

    # Tokenize the paragraphs into sentences
    reference_sentences = nlp(matches[test_name_copy]) # human written
    candidate_sentences = nlp(test_contents) # GPT Generated based on MeSH
    abstract_sentences = nlp(abstract_content) # GPT Generated based on abstract

    human_written_pos_dist = pos_distribution(reference_sentences)
    gpt_generated_pos_dist = pos_distribution(candidate_sentences)
    abstract_pos_dist = pos_distribution(abstract_sentences)

    for tag in human_written_pos_dist:
        if tag in total_pos_dist_human:
            total_pos_dist_human[tag] += human_written_pos_dist[tag]
        else:
            total_pos_dist_human[tag] = human_written_pos_dist[tag]

    for tag in gpt_generated_pos_dist:
        if tag in total_pos_dist_gpt:
            total_pos_dist_gpt[tag] += gpt_generated_pos_dist[tag]
        else:
            total_pos_dist_gpt[tag] = gpt_generated_pos_dist[tag]

    for tag in abstract_pos_dist:
        if tag in total_pos_dist_abstract:
            total_pos_dist_abstract[tag] += abstract_pos_dist[tag]
        else:
            total_pos_dist_abstract[tag] = abstract_pos_dist[tag]

    # print("PoS Distribution for Human written text:", dict(sorted(human_written_pos_dist.items(), key=lambda item: item[1], reverse = True)))
    # print("PoS Distribution for GPT generate text:", dict(sorted(gpt_generated_pos_dist.items(), key=lambda item: item[1], reverse = True)))
    # print("====================================")

    human_written_lexi_diver = lexical_diversity_by_pos(reference_sentences)
    gpt_generated_lexi_diver = lexical_diversity_by_pos(candidate_sentences)
    abstract_lexi_diver = lexical_diversity_by_pos(abstract_sentences)

    for tag in human_written_lexi_diver:
        if tag in total_lexi_diver_human:
            total_lexi_diver_human[tag] += human_written_lexi_diver[tag]
        else:
            total_lexi_diver_human[tag] = human_written_lexi_diver[tag]

    for tag in gpt_generated_lexi_diver:
        if tag in total_lexi_diver_gpt:
            total_lexi_diver_gpt[tag] += gpt_generated_lexi_diver[tag]
        else:
            total_lexi_diver_gpt[tag] = gpt_generated_lexi_diver[tag]

    for tag in abstract_lexi_diver:
        if tag in total_lexi_diver_abstract:
            total_lexi_diver_abstract[tag] += abstract_lexi_diver[tag]
        else:
            total_lexi_diver_abstract[tag] = abstract_lexi_diver[tag]


    # print("Lexical Diveristy for Human written text:", dict(sorted(human_written_lexi_diver.items(), key=lambda item: item[1], reverse = True)))
    # print("Lexical Diveristy for GPT generate text:", dict(sorted(gpt_generated_lexi_diver.items(), key=lambda item: item[1], reverse = True)))
    # print("====================================")

    human_written_tree_depth = dependency_tree_depth(reference_sentences)
    gpt_generated_tree_depth = dependency_tree_depth(candidate_sentences)
    abstract_tree_depth = dependency_tree_depth(abstract_sentences)

    # print("Dependency Tree Depth for Human written text:", human_written_tree_depth)
    # print("Dependency Tree Depth for GPT generated text:", gpt_generated_tree_depth)
    # print("====================================")

    # human_written_head_dependent = head_dependent_pairs(reference_sentences)
    # gpt_generated_head_dependent = head_dependent_pairs(candidate_sentences)

    # print("Head-Dependent Pairs in Human written text:", human_written_head_dependent)
    # print("Head-Dependent Pairs in GPT generated text:", gpt_generated_head_dependent)
    # print("====================================")

    # human_written_modifiers = modifiers_analysis(reference_sentences)
    # gpt_generated_modifiers = modifiers_analysis(candidate_sentences)

    # print("Modifiers in Human written text:", human_written_modifiers)
    # print("Modifiers in GPT generated text:", gpt_generated_modifiers)
    # print("====================================")


    human_written_complexity = syntactic_complexity(reference_sentences)
    gpt_generated_complexity = syntactic_complexity(candidate_sentences)
    abstract_complexity = syntactic_complexity(abstract_sentences)

    # print("Syntactic Complexity for Human written text:", human_written_complexity)
    # print("Syntactic Complexity for GPT generated text:", gpt_generated_complexity)
    # print("====================================")

    '''
    Question for handling syntactic ambiguity
    '''
    human_written_ambiguities = syntactic_ambiguity(reference_sentences)
    gpt_generated_ambiguities = syntactic_ambiguity(candidate_sentences)
    abstract_ambiguities = syntactic_ambiguity(abstract_sentences)

    # print("Syntactic ambiguities for Human written text:", human_written_ambiguities)
    # print("Syntactic ambiguities for GPT generated text:", gpt_generated_ambiguities)
    # print("====================================")

    # print the result of PoS
    # for token in reference_sentences:
    #     print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
    #             token.shape_, token.is_alpha, token.is_stop)
    # for token in candidate_sentences:
    #     print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
    #             token.shape_, token.is_alpha, token.is_stop)
    reference_sentences_spans = list(reference_sentences.sents)
    candidate_sentences_spans = list(candidate_sentences.sents)
    abstract_sentences_spans = list(abstract_sentences)
    # display PoS relationship with graph
    # displacy.serve(reference_sentences_spans, style="dep")
    # displacy.serve(candidate_sentences_spans, style="dep")

    total_human_written_tree_depth += human_written_tree_depth
    total_gpt_generated_tree_depth += gpt_generated_tree_depth
    total_gpt_abstract_tree_depth += abstract_tree_depth

    total_human_written_complexity += human_written_complexity
    total_gpt_generated_complexity += gpt_generated_complexity
    total_gpt_abstract_complexity += abstract_complexity

    total_human_written_ambiguities += len(human_written_ambiguities)
    total_gpt_generated_ambiguities += len(gpt_generated_ambiguities)
    total_gpt_abstract_ambiguities += len(abstract_ambiguities)

average_human_written_tree_depth = total_human_written_tree_depth / total_tests
average_gpt_generated_tree_depth = total_gpt_generated_tree_depth / total_tests
average_gpt_abstract_tree_depth = total_gpt_abstract_tree_depth / total_tests

average_human_written_complexity = total_human_written_complexity / total_tests
average_gpt_generated_complexity = total_gpt_generated_complexity / total_tests
average_gpt_abstract_complexity = total_gpt_abstract_complexity / total_tests

average_human_written_ambiguities = total_human_written_ambiguities / total_tests
average_gpt_generated_ambiguities = total_gpt_generated_ambiguities / total_tests
average_gpt_abstract_ambiguities = total_gpt_abstract_ambiguities / total_tests

for tag in total_pos_dist_human:
    total_pos_dist_human[tag] /= total_tests
for tag in total_pos_dist_gpt:
    total_pos_dist_gpt[tag] /= total_tests
for tag in total_pos_dist_abstract:
    total_pos_dist_abstract[tag] /= total_tests

for tag in total_lexi_diver_human:
    total_lexi_diver_human[tag] /= total_tests
for tag in total_lexi_diver_gpt:
    total_lexi_diver_gpt[tag] /= total_tests
for tag in total_lexi_diver_abstract:
    total_lexi_diver_abstract[tag] /= total_tests

print("Average Dependency Tree Depth for Human written text:", average_human_written_tree_depth)
print("Average Dependency Tree Depth for GPT generated text based on MeSH Terms:", average_gpt_generated_tree_depth)
print("Average Dependency Tree Depth for GPT generated text based on Abstracts:", average_gpt_abstract_tree_depth)

print("Average Syntactic Complexity for Human written text:", average_human_written_complexity)
print("Average Syntactic Complexity for GPT generated text based on MeSH Terms:", average_gpt_generated_complexity)
print("Average Syntactic Complexity for GPT generated text based on Abstracts:", average_gpt_abstract_complexity)

print("Average Syntactic Ambiguities length for Human written text:", average_human_written_ambiguities)
print("Average Syntactic Ambiguities length for GPT generated text based on MeSH Terms:", average_gpt_generated_ambiguities)
print("Average Syntactic Ambiguities for GPT generated text based on Abstracts:", average_gpt_abstract_ambiguities)

print("Average PoS Distribution for Human written text:", total_pos_dist_human)
print("Average PoS Distribution for GPT generated text based on MeSH Terms:", total_pos_dist_gpt)
print("Average PoS Distribution for GPT generated text based on Abstracts:", total_pos_dist_abstract)

print("Average Lexical Diveristy for Human written text:", total_lexi_diver_human)
print("Average Lexical Diveristy for GPT generated text based on MeSH Terms:", total_lexi_diver_gpt)
print("Average Lexical Diveristy for GPT generated text based on MeSH Terms:", total_lexi_diver_abstract)
# Out:
# Processing Hashim M. Al-Hashimi
# Processing Richard Axel
# Processing Bridget Carragher
# Processing Anum Glasgow
# Processing Stephen P. Goff
# Processing Max E. Gottesman
# Processing Eric C.  Greene
# Processing Iva S. Greenwald
# Processing Oliver Hobert
# Processing Eric Kandel
# Processing Arthur Karlin
# Processing Peter D. Kwong
# Processing Laura Landweber
# Processing Michal Levo
# Processing Stavros Lomvardas
# Processing Tom Maniatis
# Processing Richard S. Mann
# Processing Lawrence S. Shapiro
# Processing David E. Shaw
# Processing Peter A. Sims
# Processing Alexander Sobolevsky
# Processing Anna-Lena Steckelberg
# Processing Samuel Sternberg
# Processing Chaolin Zhang
# Processing Charles Zuker
# Processing Philippe J. Batut
# Processing Luke E. Berchowitz
# Processing Amanda L. Bergner
# Processing Timothy H. Bestor
# Processing Wellington V. Cardoso
# Processing Chia-Wei Cheng
# Processing Angela Christiano
# Processing Frank Costantini
# Processing Riccardo Dalla-Favera
# Processing Wayne Frankel
# Processing Jean Gautier
# Processing Vincenzo Alessandro Gennarino
# Processing Laura A. Johnston
# Processing Chao Lu
# Processing Cathy Mendelsohn
# Processing Emmanuelle Passegué
# Processing Rodney Rothstein
# Processing Eric A. Schon
# Processing Mimi Shirasu-Hiza
# Processing Mijo Simunovic
# Processing Gary Struhl
# Processing Lorraine S. Symington
# Processing Andrew Tomlinson
# Processing Aaron D Viny
# Processing Debra J Wolgemuth
# Processing Kelley Yan
# Processing Zhiguo Zhang
# Processing Rita Charon
# Processing Maya Sabatello
# Processing Alexis Walker
# Processing Caitlin McMahon
# Processing David Lamb
# Processing Rachel Yarmolinsky
# Processing Jordana Vanderselt
# Processing Cindy Smalletz
# Processing Sandra Soo-Jin Lee
# Processing Nicholas Arpaia
# Processing Uttiya Basu
# Processing Hachung Chung
# Processing Lei Ding
# Processing Donna Farber
# Processing Sankar Ghosh
# Processing Arnold Han
# Processing Yuefeng Huang
# Processing Ivaylo Ivanov
# Processing Hans-Willem Snoeck
# Processing Megan Sykes
# Processing Shan Zha
# Processing Jonathan Dworkin
# Processing David A. Fidock
# Processing Yiping W. Han
# Processing Chi-Min Ho
# Processing David D. Ho
# Processing Anne Moscona
# Processing Vincent Racaniello
# Processing Cory Abate-Shen
# Processing Henry Colecraft
# Processing Concepcion CP
# Processing Sabrina Diano
# Processing Qing R. Fan
# Processing Neil L. Harrison
# Processing Jonathan A. Javitch
# Processing Robert S. Kass
# Processing Christoph Kellendonk
# Processing Steven Owen Marx
# Processing Steven A. Siegelbaum
# Processing Susan F. Steinberg
# Processing David Sulzer
# Processing Shi Du Yan
# Processing Dian Yang
# Processing Yonghao Yu
# Processing Larry Abbott
# Processing Dmitriy Aronov
# Processing Rudy Behnia
# Processing Mark Churchland
# Processing Rui M. Costa
# Processing Aniruddha Das
# Processing Jane Dodd
# Processing Yasmine El-Shamayleh
# Processing Vincent P. Ferrera
# Processing Stefano Fusi
# Processing Vikram Gadagkar
# Processing Joseph A. Gogos
# Processing Michael Ellis Goldberg
# Processing Jacqueline Gottlieb
# Processing Wesley Grueber
# Processing Robert D. Hawkins
# Processing Elias Issa
# Processing Itamar Kahn
# Processing Minoree Kohwi
# Processing Nikolaus Kriegeskorte
# Processing Attila Losonczy
# Processing Carol A. Mason
# Processing Kenneth Miller
# Processing Liam Paninski
# Processing Serge Przedborski
# Processing Ning Qian
# Processing Kapil V. Ramachandran
# Processing Daniel Salzman
# Processing Nathaniel Sawtell
# Processing Michael Shadlen
# Processing Clarissa Waites
# Processing Hynek Wichterle
# Processing Daniel M. Wolpert
# Processing Jahar Bhattacharya
# Processing Laurence F. Abbott
# Processing Qais Al-Awqati
# Processing Manu Ben-Johny
# Processing Oliver Clarke
# Processing Joseph Gogos
# Processing Wayne Hendrickson
# Processing Jonathan Javitch
# Processing Stavroula Kousteni
# Processing X. Shawn Liu
# Processing Filippo Mancia
# Processing Andrew R. Marks
# Processing Matthias Quick
# Processing Samuel Silverstein
# Processing Tannishtha Reya
# Processing Ira Tabas
# Processing Yvon Woappi
# Processing David Knowles
# Processing Jeremy Worley
# Processing Yufeng Shen
# Processing Kam Leong
# Processing Richard Mann
# Processing Itsik Pe'er
# Processing Andrea Califano
# Processing Aris Floratos
# Processing Saeed Tavazoie
# Processing Milan Stojanovic
# Processing Gustavo Stolovitzky
# Processing Dennis Vitkup
# Processing Michael Shen
# Processing Barry Honig
# Processing Virginia Cornish
# Processing Harris Wang
# Processing Xuebing Wu
# Processing Sara Zaccara
# Processing Peter Sims
# Processing Benjamin Izar
# Processing Mikko Turunen
# Processing Harmen Bussemaker
# Processing Tuuli Lappalainen
# Processing Molly Przeworski
# Processing Dimitris Anastassiou
# Processing Raul Rabadan
# Processing Mohammed AlQuraishi
# Processing Tal Korem
# Processing Jason Adelman
# Processing David Albers
# Processing Amelia Averitt
# Processing Suzanne Bakken
# Processing Herbert Chase
# Processing James Cimino
# Processing Paul Clayton
# Processing Timothy J. Crimmins
# Processing Noémie Elhadad
# Processing Pierre Elias
# Processing Aristidis Floratos
# Processing Bruce Forman
# Processing Carol Friedman
# Processing Richard Friedman
# Processing Gamze Gürsoy
# Processing Christopher Haggerty
# Processing George Hripcsak
# Processing Shalmali Joshi
# Processing Andrew Kanter
# Processing Despina Kontos
# Processing Rita Kukafka
# Processing Gilad Kuperman
# Processing Virginia Lorenzi
# Processing Lena Mamykina
# Processing Matthew Mcdermott
# Processing Karthik Natarajan
# Processing Soojin Park
# Processing Vimla Patel
# Processing Adler Perotte
# Processing Rimma Perotte
# Processing Lauren Richter
# Processing Sarah Collins Rossetti
# Processing Patrick Ryan
# Processing Soumitra Sengupta
# Processing Steven Shea
# Processing Edward H. (ted) Shortliffe
# Processing Nicholas Tatonetti
# Processing David Vawdrey
# Processing Chunhua Weng
# Processing Xuhai Xu
# Average Dependency Tree Depth for Human written text: 11.841121495327103
# Average Dependency Tree Depth for GPT generated text based on MeSH Terms: 10.663551401869158
# Average Dependency Tree Depth for GPT generated text based on Abstracts: 13.929906542056075
# Average Syntactic Complexity for Human written text: 3.7926784783217884
# Average Syntactic Complexity for GPT generated text based on MeSH Terms: 3.8595011664414187
# Average Syntactic Complexity for GPT generated text based on Abstracts: 4.210540018912507
# Average Syntactic Ambiguities length for Human written text: 5.719626168224299
# Average Syntactic Ambiguities length for GPT generated text based on MeSH Terms: 4.196261682242991
# Average Syntactic Ambiguities for GPT generated text based on Abstracts: 8.953271028037383
# Average PoS Distribution for Human written text: {'PROPN': 44.55140186915888, 'PUNCT': 39.41121495327103, 'AUX': 7.5514018691588785, 'ADJ': 26.154205607476637, 'ADP': 31.47196261682243, 'VERB': 22.425233644859812, 'DET': 18.630841121495326, 'CCONJ': 11.350467289719626, 'NOUN': 64.39719626168224, 'PRON': 8.757009345794392, 'SPACE': 0.883177570093458, 'NUM': 4.088785046728972, 'PART': 4.093457943925234, 'ADV': 4.94392523364486, 'SCONJ': 2.0981308411214954, 'SYM': 0.9299065420560748, 'X': 0.35514018691588783, 'INTJ': 0.02336448598130841}
# Average PoS Distribution for GPT generated text based on MeSH Terms: {'NOUN': 57.07943925233645, 'PUNCT': 23.38785046728972, 'PROPN': 11.621495327102803, 'SPACE': 2.0093457943925235, 'PART': 3.350467289719626, 'ADV': 4.327102803738318, 'VERB': 15.83177570093458, 'ADP': 19.518691588785046, 'DET': 8.537383177570094, 'ADJ': 20.985981308411215, 'CCONJ': 10.542056074766355, 'PRON': 4.107476635514018, 'SCONJ': 0.5233644859813084, 'AUX': 0.4953271028037383, 'X': 0.04205607476635514, 'SYM': 0.0794392523364486, 'NUM': 0.13551401869158877}
# Average PoS Distribution for GPT generated text based on Abstracts: {'DET': 31.873831775700936, 'NOUN': 149.0607476635514, 'PART': 5.140186915887851, 'AUX': 9.434579439252337, 'VERB': 44.046728971962615, 'ADP': 52.43457943925234, 'ADJ': 51.80373831775701, 'CCONJ': 15.093457943925234, 'PUNCT': 58.8177570093458, 'PROPN': 17.514018691588785, 'ADV': 7.621495327102804, 'PRON': 7.042056074766355, 'SCONJ': 3.8130841121495327, 'X': 0.09813084112149532, 'NUM': 0.7710280373831776, 'SPACE': 0.780373831775701, 'SYM': 0.2616822429906542, 'INTJ': 0.004672897196261682}
# Average Lexical Diveristy for Human written text: {'PROPN': 30.822429906542055, 'PUNCT': 5.042056074766355, 'AUX': 3.5233644859813085, 'ADJ': 20.205607476635514, 'ADP': 9.411214953271028, 'VERB': 20.018691588785046, 'DET': 4.359813084112149, 'CCONJ': 1.5654205607476634, 'NOUN': 46.771028037383175, 'PRON': 4.934579439252336, 'SPACE': 0.3364485981308411, 'NUM': 3.369158878504673, 'PART': 1.5093457943925233, 'ADV': 4.44392523364486, 'SCONJ': 1.341121495327103, 'SYM': 0.3878504672897196, 'X': 0.3037383177570093, 'INTJ': 0.02336448598130841}
# Average Lexical Diveristy for GPT generated text based on MeSH Terms: {'NOUN': 48.36915887850467, 'PUNCT': 4.925233644859813, 'PROPN': 7.747663551401869, 'SPACE': 1.0046728971962617, 'PART': 2.0046728971962615, 'ADV': 4.11214953271028, 'VERB': 15.425233644859814, 'ADP': 9.504672897196262, 'DET': 2.336448598130841, 'ADJ': 17.7803738317757, 'CCONJ': 1.1355140186915889, 'PRON': 3.2383177570093458, 'SCONJ': 0.4766355140186916, 'AUX': 0.4719626168224299, 'X': 0.04205607476635514, 'SYM': 0.06542056074766354, 'NUM': 0.1308411214953271}
# Average Lexical Diveristy for GPT generated text based on MeSH Terms: {'DET': 5.9953271028037385, 'NOUN': 95.6355140186916, 'PART': 2.1401869158878504, 'AUX': 4.742990654205608, 'VERB': 39.3177570093458, 'ADP': 13.457943925233645, 'ADJ': 36.873831775700936, 'CCONJ': 1.308411214953271, 'PUNCT': 5.813084112149533, 'PROPN': 11.85981308411215, 'ADV': 5.925233644859813, 'PRON': 3.836448598130841, 'SCONJ': 2.294392523364486, 'X': 0.08878504672897196, 'NUM': 0.6682242990654206, 'SPACE': 0.24766355140186916, 'SYM': 0.17757009345794392, 'INTJ': 0.004672897196261682}

# %% [markdown]
# # **Visualization**

# %%
import matplotlib.pyplot as plt
# Initialize with all possible PoS tags from both dictionaries
all_pos_tags = set(total_lexi_diver_human.keys()).union(set(total_lexi_diver_gpt.keys()))

# Ensure both dictionaries have the same keys
for tag in all_pos_tags:
    total_lexi_diver_human.setdefault(tag, 0)
    total_lexi_diver_gpt.setdefault(tag, 0)
    total_lexi_diver_abstract.setdefault(tag, 0)


# Initialize with all possible PoS tags from both dictionaries
all_pos_tags = set(total_pos_dist_human.keys()).union(set(total_pos_dist_gpt.keys()))

# Ensure both dictionaries have the same keys
for tag in all_pos_tags:
    total_pos_dist_human.setdefault(tag, 0)
    total_pos_dist_gpt.setdefault(tag, 0)
    total_pos_dist_abstract.setdefault(tag, 0)

# Set up the figures and subplots
fig, axs = plt.subplots(3, 2, figsize=(15, 18))

# Dependency Tree Depth
axs[0, 0].bar(['Human', 'GPT (MeSH Terms and Keywords)', 'GPT (Abstracts)'],
              [average_human_written_tree_depth, average_gpt_generated_tree_depth, average_gpt_abstract_tree_depth],
              color=['blue', 'orange', 'green'])
axs[0, 0].set_title('Average Dependency Tree Depth')
axs[0, 0].set_ylabel('Tree Depth')
axs[0, 0].set_ylim(min([average_human_written_tree_depth, average_gpt_generated_tree_depth, average_gpt_abstract_tree_depth]) * 0.9,
                   max([average_human_written_tree_depth, average_gpt_generated_tree_depth, average_gpt_abstract_tree_depth]) * 1.1)

# Syntactic Complexity
axs[0, 1].bar(['Human', 'GPT (MeSH Terms and Keywords)', 'GPT (Abstracts)'],
              [average_human_written_complexity, average_gpt_generated_complexity, average_gpt_abstract_complexity],
              color=['blue', 'orange', 'green'])
axs[0, 1].set_title('Average Syntactic Complexity')
axs[0, 1].set_ylabel('Complexity')
axs[0, 1].set_ylim(min([average_human_written_complexity, average_gpt_generated_complexity, average_gpt_abstract_complexity]) * 0.9,
                   max([average_human_written_complexity, average_gpt_generated_complexity, average_gpt_abstract_complexity]) * 1.1)

# Syntactic Ambiguities
axs[1, 0].bar(['Human', 'GPT (MeSH Terms and Keywords)', 'GPT (Abstracts)'],
              [average_human_written_ambiguities, average_gpt_generated_ambiguities, average_gpt_abstract_ambiguities],
              color=['blue', 'orange', 'green'])
axs[1, 0].set_title('Average Syntactic Ambiguities Length')
axs[1, 0].set_ylabel('Number of Ambiguities')
axs[1, 0].set_ylim(min([average_human_written_ambiguities, average_gpt_generated_ambiguities, average_gpt_abstract_ambiguities]) * 0.9,
                   max([average_human_written_ambiguities, average_gpt_generated_ambiguities, average_gpt_abstract_ambiguities]) * 1.1)


# Part of Speech Distribution
pos_tags = list(all_pos_tags)
x = range(len(pos_tags))

# Normalize frequencies for Human
total_human = sum(total_pos_dist_human[tag] for tag in pos_tags)
normalized_human = [total_pos_dist_human[tag] / total_human for tag in pos_tags]

# Normalize frequencies for GPT (MeSH Terms and Keywords)
total_gpt = sum(total_pos_dist_gpt[tag] for tag in pos_tags)
normalized_gpt = [total_pos_dist_gpt[tag] / total_gpt for tag in pos_tags]

# Normalize frequencies for GPT (Abstracts)
total_abstract = sum(total_pos_dist_abstract[tag] for tag in pos_tags)
normalized_abstract = [total_pos_dist_abstract[tag] / total_abstract for tag in pos_tags]

# Plot normalized data
axs[1, 1].bar([i - 0.25 for i in x], normalized_human, width=0.25, label='Human', color='blue')
axs[1, 1].bar(x, normalized_gpt, width=0.25, label='GPT (MeSH Terms and Keywords)', color='orange')
axs[1, 1].bar([i + 0.25 for i in x], normalized_abstract, width=0.25, label='GPT (Abstracts)', color='green')

axs[1, 1].set_xticks(x)
axs[1, 1].set_xticklabels(pos_tags, rotation=45)
axs[1, 1].set_title('PoS Distribution by Tag')
axs[1, 1].set_ylabel('Normalized Frequency (By Percentage)')
axs[1, 1].legend()

# Lexical Diversity - assuming normalization is also desired for this
total_human_diversity = sum(total_lexi_diver_human[tag] for tag in pos_tags)
normalized_human_diversity = [total_lexi_diver_human[tag] / total_human_diversity for tag in pos_tags]

total_gpt_diversity = sum(total_lexi_diver_gpt[tag] for tag in pos_tags)
normalized_gpt_diversity = [total_lexi_diver_gpt[tag] / total_gpt_diversity for tag in pos_tags]

total_abstract_diversity = sum(total_lexi_diver_abstract[tag] for tag in pos_tags)
normalized_abstract_diversity = [total_lexi_diver_abstract[tag] / total_abstract_diversity for tag in pos_tags]

# Plot normalized data
axs[2, 0].bar([i - 0.25 for i in x], normalized_human_diversity, width=0.25, label='Human', color='blue')
axs[2, 0].bar(x, normalized_gpt_diversity, width=0.25, label='GPT (MeSH Terms and Keywords)', color='orange')
axs[2, 0].bar([i + 0.25 for i in x], normalized_abstract_diversity, width=0.25, label='GPT (Abstracts)', color='green')

axs[2, 0].set_xticks(x)
axs[2, 0].set_xticklabels(pos_tags, rotation=45)
axs[2, 0].set_title('Lexical Diversity by PoS Tag')
axs[2, 0].set_ylabel('Normalized Diversity Score (By Percentage)')
axs[2, 0].legend()

plt.tight_layout()
fig.delaxes(axs[2, 1])  # Remove the last (empty) subplot
plt.show()

# %% [markdown]
# # **Dependency Parsing**

# %%
import spacy
from spacy import displacy
counter = 0
nlp = spacy.load("en_core_web_sm")
for test_name in matches:
    print(f"Processing {test_name}")
    test_name_copy = test_name
    test_name = test_name.split(" ")
    test_first_name, test_last_name = test_name[0], test_name[-1]
    test_path = candidate_path + '/' + file_names_dict[(test_first_name, test_last_name)]

    with open(test_path, 'r', encoding='utf-8') as file:
        test_contents = file.read()

    # Tokenize the paragraphs into sentences
    reference_sentences = nlp(matches[test_name_copy]) # human written
    candidate_sentences = nlp(test_contents) # GPT Generated

    for token in reference_sentences:
        print(f"Token: {token.text}, Head: {token.head.text}, Dep: {token.dep_}, POS: {token.pos_}")
    for token in candidate_sentences:
        print(f"Token: {token.text}, Head: {token.head.text}, Dep: {token.dep_}, POS: {token.pos_}")

    # Visualizing the dependency parse tree
    displacy.render(reference_sentences, style="dep", jupyter=True, options={'distance': 90})
    displacy.render(candidate_sentences, style="dep", jupyter=True, options={'distance': 90})
    if counter == 0:
        break
# Out:
# Processing Hashim M. Al-Hashimi
# Token: Al, Head: Hashimi, Dep: compound, POS: PROPN
# Token: -, Head: Hashimi, Dep: punct, POS: PUNCT
# Token: Hashimi, Head: is, Dep: nsubj, POS: PROPN
# Token: is, Head: is, Dep: ROOT, POS: AUX
# Token: interested, Head: is, Dep: acomp, POS: ADJ
# Token: in, Head: interested, Dep: prep, POS: ADP
# Token: developing, Head: in, Dep: pcomp, POS: VERB
# Token: a, Head: understanding, Dep: det, POS: DET
# Token: deep, Head: quantitative, Dep: amod, POS: ADJ
# Token: ,, Head: quantitative, Dep: punct, POS: PUNCT
# Token: quantitative, Head: understanding, Dep: amod, POS: ADJ
# Token: ,, Head: quantitative, Dep: punct, POS: PUNCT
# Token: and, Head: quantitative, Dep: cc, POS: CCONJ
# Token: predictive, Head: understanding, Dep: amod, POS: ADJ
# Token: understanding, Head: developing, Dep: dobj, POS: NOUN
# Token: of, Head: understanding, Dep: prep, POS: ADP
# Token: cellular, Head: processes, Dep: amod, POS: ADJ
# Token: processes, Head: of, Dep: pobj, POS: NOUN
# Token: based, Head: processes, Dep: acl, POS: VERB
# Token: on, Head: based, Dep: prep, POS: ADP
# Token: the, Head: behaviors, Dep: det, POS: DET
# Token: fundamental, Head: behaviors, Dep: amod, POS: ADJ
# Token: behaviors, Head: on, Dep: pobj, POS: NOUN
# Token: of, Head: behaviors, Dep: prep, POS: ADP
# Token: nucleic, Head: acids, Dep: amod, POS: ADJ
# Token: acids, Head: of, Dep: pobj, POS: NOUN
# Token: and, Head: acids, Dep: cc, POS: CCONJ
# Token: their, Head: interactions, Dep: poss, POS: PRON
# Token: interactions, Head: acids, Dep: conj, POS: NOUN
# Token: with, Head: interactions, Dep: prep, POS: ADP
# Token: protein, Head: binding, Dep: npadvmod, POS: NOUN
# Token: binding, Head: partners, Dep: amod, POS: VERB
# Token: partners, Head: with, Dep: pobj, POS: NOUN
# Token: ., Head: is, Dep: punct, POS: PUNCT
# Token:   , Head: ., Dep: dep, POS: SPACE
# Token: Over, Head: developed, Dep: prep, POS: ADP
# Token: the, Head: decades, Dep: det, POS: DET
# Token: past, Head: decades, Dep: amod, POS: ADJ
# Token: two, Head: decades, Dep: nummod, POS: NUM
# Token: decades, Head: Over, Dep: pobj, POS: NOUN
# Token: ,, Head: developed, Dep: punct, POS: PUNCT
# Token: Al, Head: Hashimi, Dep: compound, POS: PROPN
# Token: -, Head: Hashimi, Dep: punct, POS: PUNCT
# Token: Hashimi, Head: developed, Dep: nsubj, POS: PROPN
# Token: and, Head: Hashimi, Dep: cc, POS: CCONJ
# Token: his, Head: trainees, Dep: poss, POS: PRON
# Token: trainees, Head: Hashimi, Dep: conj, POS: NOUN
# Token: developed, Head: developed, Dep: ROOT, POS: VERB
# Token: approaches, Head: developed, Dep: dobj, POS: NOUN
# Token: combining, Head: approaches, Dep: acl, POS: VERB
# Token: NMR, Head: spectroscopy, Dep: compound, POS: PROPN
# Token: spectroscopy, Head: combining, Dep: dobj, POS: NOUN
# Token: ,, Head: spectroscopy, Dep: punct, POS: PUNCT
# Token: computational, Head: modeling, Dep: amod, POS: ADJ
# Token: modeling, Head: spectroscopy, Dep: conj, POS: NOUN
# Token: ,, Head: developed, Dep: punct, POS: PUNCT
# Token: optical, Head: experiments, Dep: amod, POS: ADJ
# Token: melting, Head: experiments, Dep: compound, POS: NOUN
# Token: experiments, Head: approaches, Dep: appos, POS: NOUN
# Token: ,, Head: experiments, Dep: punct, POS: PUNCT
# Token: and, Head: experiments, Dep: cc, POS: CCONJ
# Token: chemical, Head: experiments, Dep: conj, POS: NOUN
# Token: probing, Head: chemical, Dep: acl, POS: VERB
# Token: to, Head: determine, Dep: aux, POS: PART
# Token: determine, Head: probing, Dep: xcomp, POS: VERB
# Token: 3D, Head: ensembles, Dep: amod, POS: ADJ
# Token: dynamic, Head: ensembles, Dep: amod, POS: ADJ
# Token: ensembles, Head: determine, Dep: dobj, POS: NOUN
# Token: of, Head: ensembles, Dep: prep, POS: ADP
# Token: RNA, Head: molecules, Dep: nmod, POS: PROPN
# Token: and, Head: RNA, Dep: cc, POS: CCONJ
# Token: DNA, Head: molecules, Dep: compound, POS: PROPN
# Token: molecules, Head: of, Dep: pobj, POS: NOUN
# Token: at, Head: determine, Dep: prep, POS: ADP
# Token: atomic, Head: resolution, Dep: amod, POS: ADJ
# Token: resolution, Head: at, Dep: pobj, POS: NOUN
# Token: ., Head: developed, Dep: punct, POS: PUNCT
# Token:   , Head: ., Dep: dep, POS: SPACE
# Token: Using, Head: developed, Dep: advcl, POS: VERB
# Token: dynamic, Head: ensembles, Dep: amod, POS: ADJ
# Token: ensembles, Head: Using, Dep: dobj, POS: NOUN
# Token: of, Head: ensembles, Dep: prep, POS: ADP
# Token: nucleic, Head: acids, Dep: amod, POS: ADJ
# Token: acids, Head: of, Dep: pobj, POS: NOUN
# Token: ,, Head: developed, Dep: punct, POS: PUNCT
# Token: the, Head: group, Dep: det, POS: DET
# Token: Al, Head: Hashimi, Dep: compound, POS: PROPN
# Token: -, Head: Hashimi, Dep: punct, POS: PUNCT
# Token: Hashimi, Head: group, Dep: compound, POS: PROPN
# Token: group, Head: developed, Dep: nsubj, POS: NOUN
# Token: has, Head: developed, Dep: aux, POS: AUX
# Token: developed, Head: developed, Dep: ROOT, POS: VERB
# Token: quantitative, Head: models, Dep: amod, POS: ADJ
# Token: and, Head: quantitative, Dep: cc, POS: CCONJ
# Token: predictive, Head: quantitative, Dep: conj, POS: ADJ
# Token: models, Head: developed, Dep: dobj, POS: NOUN
# Token: for, Head: models, Dep: prep, POS: ADP
# Token: several, Head: processes, Dep: amod, POS: ADJ
# Token: fundamental, Head: processes, Dep: amod, POS: ADJ
# Token: biological, Head: processes, Dep: amod, POS: ADJ
# Token: processes, Head: for, Dep: pobj, POS: NOUN
# Token: ,, Head: processes, Dep: punct, POS: PUNCT
# Token: including, Head: processes, Dep: prep, POS: VERB
# Token: DNA, Head: replication, Dep: compound, POS: NOUN
# Token: replication, Head: fidelity, Dep: compound, POS: NOUN
# Token: fidelity, Head: including, Dep: pobj, POS: NOUN
# Token: ,, Head: fidelity, Dep: punct, POS: PUNCT
# Token: Tat, Head: dependent, Dep: amod, POS: PROPN
# Token: -, Head: dependent, Dep: punct, POS: PUNCT
# Token: dependent, Head: HIV-1, Dep: amod, POS: ADJ
# Token: HIV-1, Head: activation, Dep: nmod, POS: PROPN
# Token: transcriptional, Head: activation, Dep: amod, POS: ADJ
# Token: activation, Head: fidelity, Dep: conj, POS: NOUN
# Token: ,, Head: fidelity, Dep: punct, POS: PUNCT
# Token: RNA, Head: folding, Dep: nsubj, POS: PROPN
# Token: folding, Head: fidelity, Dep: conj, POS: VERB
# Token: ,, Head: folding, Dep: punct, POS: PUNCT
# Token: and, Head: folding, Dep: cc, POS: CCONJ
# Token: the, Head: impact, Dep: det, POS: DET
# Token: impact, Head: fidelity, Dep: conj, POS: NOUN
# Token: of, Head: impact, Dep: prep, POS: ADP
# Token: post, Head: modifications, Dep: amod, POS: ADJ
# Token: -, Head: modifications, Dep: amod, POS: ADJ
# Token: transcriptional, Head: modifications, Dep: amod, POS: ADJ
# Token: modifications, Head: of, Dep: pobj, POS: NOUN
# Token: such, Head: as, Dep: amod, POS: ADJ
# Token: as, Head: modifications, Dep: prep, POS: ADP
# Token: m6A, Head: as, Dep: pobj, POS: PROPN
# Token: and, Head: m6A, Dep: cc, POS: CCONJ
# Token: Nm, Head: m6A, Dep: conj, POS: PROPN
# Token: on, Head: impact, Dep: prep, POS: ADP
# Token: translation, Head: on, Dep: pobj, POS: NOUN
# Token: ,, Head: translation, Dep: punct, POS: PUNCT
# Token: splicing, Head: translation, Dep: conj, POS: NOUN
# Token: ,, Head: splicing, Dep: punct, POS: PUNCT
# Token: and, Head: splicing, Dep: cc, POS: CCONJ
# Token: RNA, Head: protein, Dep: compound, POS: PROPN
# Token: -, Head: protein, Dep: punct, POS: ADJ
# Token: protein, Head: interactions, Dep: compound, POS: NOUN
# Token: interactions, Head: splicing, Dep: conj, POS: NOUN
# Token: ., Head: developed, Dep: punct, POS: PUNCT
# Token:   , Head: ., Dep: dep, POS: SPACE
# Token: These, Head: studies, Dep: det, POS: DET
# Token: studies, Head: reshaped, Dep: nsubj, POS: NOUN
# Token: have, Head: reshaped, Dep: aux, POS: AUX
# Token: reshaped, Head: reshaped, Dep: ROOT, POS: VERB
# Token: structural, Head: biology, Dep: amod, POS: ADJ
# Token: biology, Head: reshaped, Dep: dobj, POS: NOUN
# Token: ,, Head: reshaped, Dep: punct, POS: PUNCT
# Token: revealing, Head: reshaped, Dep: advcl, POS: VERB
# Token: dynamic, Head: ensembles, Dep: amod, POS: ADJ
# Token: ensembles, Head: revealing, Dep: dobj, POS: NOUN
# Token: as, Head: revealing, Dep: prep, POS: ADP
# Token: the, Head: behavior, Dep: det, POS: DET
# Token: fundamental, Head: behavior, Dep: amod, POS: ADJ
# Token: behavior, Head: as, Dep: pobj, POS: NOUN
# Token: of, Head: behavior, Dep: prep, POS: ADP
# Token: biomolecules, Head: of, Dep: pobj, POS: NOUN
# Token: needed, Head: biomolecules, Dep: acl, POS: VERB
# Token: to, Head: understand, Dep: aux, POS: PART
# Token: understand, Head: needed, Dep: xcomp, POS: VERB
# Token: and, Head: understand, Dep: cc, POS: CCONJ
# Token: predict, Head: understand, Dep: conj, POS: VERB
# Token: cellular, Head: activity, Dep: amod, POS: ADJ
# Token: activity, Head: predict, Dep: dobj, POS: NOUN
# Token: quantitatively, Head: predict, Dep: advmod, POS: ADV
# Token: ., Head: reshaped, Dep: punct, POS: PUNCT
# Token: The, Head: lab, Dep: det, POS: DET
# Token: Al, Head: Hashimi, Dep: compound, POS: PROPN
# Token: -, Head: Hashimi, Dep: punct, POS: PUNCT
# Token: Hashimi, Head: lab, Dep: compound, POS: PROPN
# Token: lab, Head: using, Dep: nsubj, POS: NOUN
# Token: is, Head: using, Dep: aux, POS: AUX
# Token: currently, Head: using, Dep: advmod, POS: ADV
# Token: using, Head: using, Dep: ROOT, POS: VERB
# Token: dynamic, Head: ensembles, Dep: amod, POS: ADJ
# Token: ensembles, Head: using, Dep: dobj, POS: NOUN
# Token: to, Head: reconstitute, Dep: aux, POS: PART
# Token: reconstitute, Head: using, Dep: xcomp, POS: VERB
# Token: the, Head: activities, Dep: det, POS: DET
# Token: folding, Head: activities, Dep: amod, POS: VERB
# Token: and, Head: folding, Dep: cc, POS: CCONJ
# Token: cellular, Head: folding, Dep: conj, POS: ADJ
# Token: activities, Head: reconstitute, Dep: dobj, POS: NOUN
# Token: of, Head: activities, Dep: prep, POS: ADP
# Token: viral, Head: RNAs, Dep: amod, POS: ADJ
# Token: and, Head: viral, Dep: cc, POS: CCONJ
# Token: other, Head: viral, Dep: conj, POS: ADJ
# Token: non, Head: RNAs, Dep: amod, POS: ADJ
# Token: -, Head: RNAs, Dep: amod, POS: ADJ
# Token: coding, Head: RNAs, Dep: amod, POS: ADJ
# Token: RNAs, Head: of, Dep: pobj, POS: NOUN
# Token: ,, Head: reconstitute, Dep: punct, POS: PUNCT
# Token: to, Head: determine, Dep: aux, POS: PART
# Token: determine, Head: using, Dep: xcomp, POS: VERB
# Token: the, Head: role, Dep: det, POS: DET
# Token: role, Head: determine, Dep: dobj, POS: NOUN
# Token: of, Head: role, Dep: prep, POS: ADP
# Token: DNA, Head: dynamics, Dep: nmod, POS: NOUN
# Token: structural, Head: dynamics, Dep: amod, POS: ADJ
# Token: dynamics, Head: of, Dep: pobj, POS: NOUN
# Token: in, Head: role, Dep: prep, POS: ADP
# Token: shaping, Head: in, Dep: pcomp, POS: VERB
# Token: the, Head: probabilities, Dep: det, POS: DET
# Token: probabilities, Head: shaping, Dep: dobj, POS: NOUN
# Token: of, Head: probabilities, Dep: prep, POS: ADP
# Token: mutagenesis, Head: of, Dep: pobj, POS: NOUN
# Token: and, Head: mutagenesis, Dep: cc, POS: CCONJ
# Token: cancer, Head: mutagenesis, Dep: conj, POS: NOUN
# Token: ,, Head: shaping, Dep: punct, POS: PUNCT
# Token: and, Head: shaping, Dep: cc, POS: CCONJ
# Token: to, Head: design, Dep: aux, POS: PART
# Token: rationally, Head: design, Dep: advmod, POS: ADV
# Token: design, Head: shaping, Dep: conj, POS: VERB
# Token: inhibitors, Head: design, Dep: dobj, POS: NOUN
# Token: targeting, Head: inhibitors, Dep: acl, POS: VERB
# Token: viral, Head: elements, Dep: amod, POS: ADJ
# Token: RNA, Head: elements, Dep: nmod, POS: PROPN
# Token: regulatory, Head: elements, Dep: amod, POS: ADJ
# Token: elements, Head: targeting, Dep: dobj, POS: NOUN
# Token: in, Head: elements, Dep: prep, POS: ADP
# Token: HIV-1, Head: in, Dep: pobj, POS: PROPN
# Token: and, Head: HIV-1, Dep: cc, POS: CCONJ
# Token: SARS, Head: CoV-2, Dep: compound, POS: PROPN
# Token: -, Head: CoV-2, Dep: punct, POS: PUNCT
# Token: CoV-2, Head: HIV-1, Dep: conj, POS: PROPN
# Token: as, Head: as, Dep: advmod, POS: ADV
# Token: well, Head: as, Dep: advmod, POS: ADV
# Token: as, Head: HIV-1, Dep: cc, POS: ADP
# Token: non, Head: RNAs, Dep: amod, POS: ADJ
# Token: -, Head: RNAs, Dep: amod, POS: ADJ
# Token: coding, Head: RNAs, Dep: amod, POS: ADJ
# Token: RNAs, Head: HIV-1, Dep: conj, POS: NOUN
# Token: involved, Head: RNAs, Dep: acl, POS: VERB
# Token: in, Head: involved, Dep: prep, POS: ADP
# Token: cancer, Head: in, Dep: pobj, POS: NOUN
# Token: ., Head: using, Dep: punct, POS: PUNCT
# Token:   , Head: ., Dep: dep, POS: SPACE
# Token: Efforts, Head: include, Dep: nsubj, POS: NOUN
# Token: include, Head: include, Dep: ROOT, POS: VERB
# Token: developing, Head: include, Dep: xcomp, POS: VERB
# Token: and, Head: developing, Dep: cc, POS: CCONJ
# Token: applying, Head: developing, Dep: conj, POS: VERB
# Token: high, Head: throughput, Dep: amod, POS: ADJ
# Token: throughput, Head: approaches, Dep: nmod, POS: NOUN
# Token: sequencing, Head: based, Dep: npadvmod, POS: VERB
# Token: -, Head: based, Dep: punct, POS: PUNCT
# Token: based, Head: approaches, Dep: amod, POS: VERB
# Token: approaches, Head: applying, Dep: dobj, POS: NOUN
# Token: to, Head: map, Dep: aux, POS: PART
# Token: map, Head: applying, Dep: advcl, POS: VERB
# Token: DNA, Head: dynamics, Dep: nmod, POS: PROPN
# Token: structural, Head: dynamics, Dep: amod, POS: ADJ
# Token: dynamics, Head: map, Dep: dobj, POS: NOUN
# Token: genome, Head: wide, Dep: advmod, POS: ADV
# Token: -, Head: wide, Dep: punct, POS: PUNCT
# Token: wide, Head: map, Dep: advmod, POS: ADJ
# Token: ,, Head: map, Dep: punct, POS: PUNCT
# Token: developing, Head: map, Dep: conj, POS: VERB
# Token: high, Head: assays, Dep: amod, POS: ADJ
# Token: throughput, Head: assays, Dep: compound, POS: NOUN
# Token: assays, Head: developing, Dep: dobj, POS: NOUN
# Token: for, Head: developing, Dep: prep, POS: ADP
# Token: quantitatively, Head: measuring, Dep: advmod, POS: ADV
# Token: measuring, Head: for, Dep: pcomp, POS: VERB
# Token: the, Head: activity, Dep: det, POS: DET
# Token: activity, Head: measuring, Dep: dobj, POS: NOUN
# Token: of, Head: activity, Dep: prep, POS: ADP
# Token: various, Head: steps, Dep: amod, POS: ADJ
# Token: steps, Head: of, Dep: pobj, POS: NOUN
# Token: in, Head: steps, Dep: prep, POS: ADP
# Token: the, Head: lifecycle, Dep: det, POS: DET
# Token: HIV-1, Head: lifecycle, Dep: compound, POS: PROPN
# Token: lifecycle, Head: in, Dep: pobj, POS: NOUN
# Token: ,, Head: include, Dep: punct, POS: PUNCT
# Token: and, Head: include, Dep: cc, POS: CCONJ
# Token: determining, Head: include, Dep: conj, POS: VERB
# Token: an, Head: atlas, Dep: det, POS: DET
# Token: atlas, Head: determining, Dep: dobj, POS: NOUN
# Token: of, Head: atlas, Dep: prep, POS: ADP
# Token: dynamic, Head: ensembles, Dep: amod, POS: ADJ
# Token: ensembles, Head: of, Dep: pobj, POS: NOUN
# Token: for, Head: determining, Dep: prep, POS: ADP
# Token: all, Head: motifs, Dep: det, POS: DET
# Token: nucleic, Head: motifs, Dep: amod, POS: ADJ
# Token: acid, Head: motifs, Dep: amod, POS: NOUN
# Token: building, Head: block, Dep: compound, POS: NOUN
# Token: block, Head: motifs, Dep: compound, POS: NOUN
# Token: motifs, Head: for, Dep: pobj, POS: NOUN
# Token: ., Head: include, Dep: punct, POS: PUNCT
# Token:   , Head: ., Dep: dep, POS: SPACE
# Token: A, Head: area, Dep: det, POS: DET
# Token: more, Head: recent, Dep: advmod, POS: ADV
# Token: recent, Head: area, Dep: amod, POS: ADJ
# Token: area, Head: includes, Dep: nsubj, POS: NOUN
# Token: includes, Head: includes, Dep: ROOT, POS: VERB
# Token: efforts, Head: includes, Dep: dobj, POS: NOUN
# Token: to, Head: digitize, Dep: aux, POS: PART
# Token: digitize, Head: efforts, Dep: acl, POS: VERB
# Token: biochemistry, Head: digitize, Dep: dobj, POS: NOUN
# Token: by, Head: digitize, Dep: prep, POS: ADP
# Token: describing, Head: by, Dep: pcomp, POS: VERB
# Token: biomolecules, Head: describing, Dep: dobj, POS: NOUN
# Token: in, Head: describing, Dep: prep, POS: ADP
# Token: terms, Head: in, Dep: pobj, POS: NOUN
# Token: of, Head: terms, Dep: prep, POS: ADP
# Token: finite, Head: computing, Dep: amod, POS: ADJ
# Token: -, Head: computing, Dep: punct, POS: PUNCT
# Token: state, Head: computing, Dep: npadvmod, POS: NOUN
# Token: -, Head: computing, Dep: punct, POS: PUNCT
# Token: computing, Head: machines, Dep: amod, POS: VERB
# Token: machines, Head: of, Dep: pobj, POS: NOUN
# Token: and, Head: describing, Dep: cc, POS: CCONJ
# Token: applying, Head: describing, Dep: conj, POS: VERB
# Token: complexity, Head: theory, Dep: compound, POS: NOUN
# Token: theory, Head: applying, Dep: dobj, POS: NOUN
# Token: to, Head: applying, Dep: prep, POS: ADP
# Token: classifying, Head: to, Dep: pcomp, POS: VERB
# Token: biochemical, Head: reactions, Dep: amod, POS: ADJ
# Token: reactions, Head: classifying, Dep: dobj, POS: NOUN
# Token: ., Head: includes, Dep: punct, POS: PUNCT
# Token: As, Head: is, Dep: prep, POS: ADP
# Token: a, Head: mentor, Dep: det, POS: DET
# Token: mentor, Head: As, Dep: pobj, POS: NOUN
# Token: ,, Head: is, Dep: punct, POS: PUNCT
# Token: Al, Head: Hashimi, Dep: compound, POS: PROPN
# Token: -, Head: Hashimi, Dep: punct, POS: PUNCT
# Token: Hashimi, Head: is, Dep: nsubj, POS: PROPN
# Token: is, Head: is, Dep: ROOT, POS: AUX
# Token: strongly, Head: committed, Dep: advmod, POS: ADV
# Token: committed, Head: is, Dep: acomp, POS: ADJ
# Token: to, Head: committed, Dep: prep, POS: ADP
# Token: creating, Head: to, Dep: pcomp, POS: VERB
# Token: a, Head: environment, Dep: det, POS: DET
# Token: welcoming, Head: environment, Dep: nmod, POS: NOUN
# Token: ,, Head: welcoming, Dep: punct, POS: PUNCT
# Token: enriching, Head: welcoming, Dep: conj, POS: NOUN
# Token: ,, Head: enriching, Dep: punct, POS: PUNCT
# Token: and, Head: enriching, Dep: cc, POS: CCONJ
# Token: supportive, Head: environment, Dep: amod, POS: ADJ
# Token: environment, Head: creating, Dep: dobj, POS: NOUN
# Token: for, Head: environment, Dep: prep, POS: ADP
# Token: all, Head: trainees, Dep: predet, POS: DET
# Token: his, Head: trainees, Dep: poss, POS: PRON
# Token: trainees, Head: for, Dep: pobj, POS: NOUN
# Token: and, Head: creating, Dep: cc, POS: CCONJ
# Token: effectively, Head: preparing, Dep: advmod, POS: ADV
# Token: preparing, Head: creating, Dep: conj, POS: VERB
# Token: them, Head: preparing, Dep: dobj, POS: PRON
# Token: for, Head: preparing, Dep: prep, POS: ADP
# Token: careers, Head: for, Dep: pobj, POS: NOUN
# Token: in, Head: careers, Dep: prep, POS: ADP
# Token: science, Head: in, Dep: pobj, POS: NOUN
# Token: ., Head: is, Dep: punct, POS: PUNCT
# Token:   , Head: ., Dep: dep, POS: SPACE
# Token: To, Head: trained, Dep: prep, POS: ADP
# Token: date, Head: To, Dep: pobj, POS: NOUN
# Token: ,, Head: trained, Dep: punct, POS: PUNCT
# Token: he, Head: trained, Dep: nsubj, POS: PRON
# Token: has, Head: trained, Dep: aux, POS: AUX
# Token: trained, Head: trained, Dep: ROOT, POS: VERB
# Token: over, Head: five, Dep: quantmod, POS: ADP
# Token: thirty, Head: five, Dep: compound, POS: NUM
# Token: -, Head: five, Dep: punct, POS: PUNCT
# Token: five, Head: students, Dep: nummod, POS: NUM
# Token: graduate, Head: students, Dep: amod, POS: ADJ
# Token: students, Head: trained, Dep: dobj, POS: NOUN
# Token: and, Head: students, Dep: cc, POS: CCONJ
# Token: postdoctoral, Head: fellows, Dep: compound, POS: NOUN
# Token: fellows, Head: students, Dep: conj, POS: NOUN
# Token: with, Head: students, Dep: prep, POS: ADP
# Token: backgrounds, Head: with, Dep: pobj, POS: NOUN
# Token: in, Head: backgrounds, Dep: prep, POS: ADP
# Token: biochemistry, Head: in, Dep: pobj, POS: NOUN
# Token: ,, Head: biochemistry, Dep: punct, POS: PUNCT
# Token: cell, Head: biology, Dep: compound, POS: NOUN
# Token: biology, Head: biochemistry, Dep: conj, POS: NOUN
# Token: ,, Head: biology, Dep: punct, POS: PUNCT
# Token: chemistry, Head: biology, Dep: conj, POS: NOUN
# Token: ,, Head: chemistry, Dep: punct, POS: PUNCT
# Token: computer, Head: science, Dep: compound, POS: NOUN
# Token: science, Head: chemistry, Dep: conj, POS: NOUN
# Token: ,, Head: science, Dep: punct, POS: PUNCT
# Token: physics, Head: science, Dep: conj, POS: NOUN
# Token: ,, Head: physics, Dep: punct, POS: PUNCT
# Token: and, Head: physics, Dep: cc, POS: CCONJ
# Token: mathematics, Head: physics, Dep: conj, POS: NOUN
# Token: ., Head: trained, Dep: punct, POS: PUNCT
# Token:   , Head: ., Dep: dep, POS: SPACE
# Token: His, Head: alumni, Dep: poss, POS: PRON
# Token: alumni, Head: include, Dep: nsubj, POS: NOUN
# Token: include, Head: include, Dep: ROOT, POS: VERB
# Token: heads, Head: include, Dep: dobj, POS: NOUN
# Token: of, Head: heads, Dep: prep, POS: ADP
# Token: laboratories, Head: of, Dep: pobj, POS: NOUN
# Token: at, Head: heads, Dep: prep, POS: ADP
# Token: universities, Head: at, Dep: pobj, POS: NOUN
# Token: in, Head: universities, Dep: prep, POS: ADP
# Token: the, Head: US, Dep: det, POS: DET
# Token: US, Head: in, Dep: pobj, POS: PROPN
# Token: ,, Head: US, Dep: punct, POS: PUNCT
# Token: France, Head: US, Dep: conj, POS: PROPN
# Token: ,, Head: France, Dep: punct, POS: PUNCT
# Token: Sweden, Head: France, Dep: conj, POS: PROPN
# Token: ,, Head: Sweden, Dep: punct, POS: PUNCT
# Token: India, Head: Sweden, Dep: conj, POS: PROPN
# Token: ,, Head: India, Dep: punct, POS: PUNCT
# Token: and, Head: India, Dep: cc, POS: CCONJ
# Token: China, Head: India, Dep: conj, POS: PROPN
# Token: and, Head: China, Dep: cc, POS: CCONJ
# Token: scientists, Head: China, Dep: conj, POS: NOUN
# Token: at, Head: scientists, Dep: prep, POS: ADP
# Token: many, Head: companies, Dep: amod, POS: ADJ
# Token: biotech, Head: companies, Dep: amod, POS: ADJ
# Token: companies, Head: at, Dep: pobj, POS: NOUN
# Token: ,, Head: companies, Dep: punct, POS: PUNCT
# Token: large, Head: firms, Dep: amod, POS: ADJ
# Token: pharmaceutical, Head: firms, Dep: amod, POS: ADJ
# Token: firms, Head: companies, Dep: conj, POS: NOUN
# Token: ,, Head: firms, Dep: punct, POS: PUNCT
# Token: and, Head: firms, Dep: cc, POS: CCONJ
# Token: management, Head: consulting, Dep: compound, POS: NOUN
# Token: consulting, Head: firms, Dep: compound, POS: NOUN
# Token: firms, Head: firms, Dep: conj, POS: NOUN
# Token: ., Head: include, Dep: punct, POS: PUNCT
# Token:   , Head: ., Dep: dep, POS: SPACE
# Token: Over, Head: 30, Dep: quantmod, POS: ADP
# Token: 30, Head: undergraduates, Dep: nummod, POS: NUM
# Token: undergraduates, Head: worked, Dep: nsubj, POS: NOUN
# Token: have, Head: worked, Dep: aux, POS: AUX
# Token: also, Head: worked, Dep: advmod, POS: ADV
# Token: worked, Head: worked, Dep: ROOT, POS: VERB
# Token: in, Head: worked, Dep: prep, POS: ADP
# Token: the, Head: laboratory, Dep: det, POS: DET
# Token: Al, Head: Hashimi, Dep: compound, POS: PROPN
# Token: -, Head: Hashimi, Dep: punct, POS: PUNCT
# Token: Hashimi, Head: laboratory, Dep: compound, POS: PROPN
# Token: laboratory, Head: in, Dep: pobj, POS: NOUN
# Token: ., Head: worked, Dep: punct, POS: PUNCT
# Token: Al, Head: Lab, Dep: nmod, POS: PROPN
# Token: -, Head: Lab, Dep: punct, POS: PUNCT
# Token: Hashimi, Head: Lab, Dep: nmod, POS: PROPN
# Token: Lab, Head: Lab, Dep: ROOT, POS: PROPN
# Token: :, Head: hashimi, Dep: punct, POS: PUNCT
# Token: https://www.biochem.cuimc.columbia.edu, Head: labs, Dep: nmod, POS: PROPN
# Token: /, Head: labs, Dep: punct, POS: SYM
# Token: research, Head: labs, Dep: nmod, POS: NOUN
# Token: /, Head: labs, Dep: punct, POS: SYM
# Token: research, Head: labs, Dep: compound, POS: NOUN
# Token: -, Head: labs, Dep: punct, POS: PUNCT
# Token: labs, Head: hashimi, Dep: nmod, POS: PROPN
# Token: /, Head: hashimi, Dep: punct, POS: SYM
# Token: al, Head: hashimi, Dep: compound, POS: PROPN
# Token: -, Head: hashimi, Dep: punct, POS: PUNCT
# Token: hashimi, Head: Lab, Dep: appos, POS: PROPN
# Token: ..., Head: Lab, Dep: punct, POS: PUNCT
# Token: Researcher, Head: focuses, Dep: nsubj, POS: NOUN
# Token: :, Head: Researcher, Dep: punct, POS: PUNCT
# Token: Hashim, Head: Overview, Dep: compound, POS: PROPN
# Token: M., Head: Overview, Dep: compound, POS: PROPN
# Token: Al, Head: Hashimi, Dep: compound, POS: PROPN
# Token: -, Head: Hashimi, Dep: punct, POS: PUNCT
# Token: Hashimi, Head: Overview, Dep: compound, POS: PROPN
# Token:
# , Head: Hashimi, Dep: dep, POS: SPACE
# Token: Research, Head: Overview, Dep: compound, POS: PROPN
# Token: Overview, Head: Researcher, Dep: appos, POS: PROPN
# Token: :, Head: Overview, Dep: punct, POS: PUNCT
# Token:
# , Head: :, Dep: dep, POS: SPACE
# Token: Hashim, Head: Hashimi, Dep: compound, POS: PROPN
# Token: M., Head: Hashimi, Dep: compound, POS: PROPN
# Token: Al, Head: Hashimi, Dep: compound, POS: PROPN
# Token: -, Head: Hashimi, Dep: punct, POS: PUNCT
# Token: Hashimi, Head: research, Dep: poss, POS: PROPN
# Token: 's, Head: Hashimi, Dep: case, POS: PART
# Token: research, Head: Overview, Dep: appos, POS: NOUN
# Token: primarily, Head: focuses, Dep: advmod, POS: ADV
# Token: focuses, Head: focuses, Dep: ROOT, POS: VERB
# Token: on, Head: focuses, Dep: prep, POS: ADP
# Token: the, Head: dynamics, Dep: det, POS: DET
# Token: intricate, Head: dynamics, Dep: amod, POS: ADJ
# Token: dynamics, Head: on, Dep: pobj, POS: NOUN
# Token: of, Head: dynamics, Dep: prep, POS: ADP
# Token: nucleic, Head: acids, Dep: amod, POS: ADJ
# Token: acids, Head: of, Dep: pobj, POS: NOUN
# Token: ,, Head: dynamics, Dep: punct, POS: PUNCT
# Token: especially, Head: in, Dep: advmod, POS: ADV
# Token: in, Head: dynamics, Dep: prep, POS: ADP
# Token: relation, Head: in, Dep: pobj, POS: NOUN
# Token: to, Head: relation, Dep: prep, POS: ADP
# Token: DNA, Head: damage, Dep: compound, POS: NOUN
# Token: damage, Head: to, Dep: pobj, POS: NOUN
# Token: and, Head: relation, Dep: cc, POS: CCONJ
# Token: the, Head: mechanisms, Dep: det, POS: DET
# Token: recognition, Head: mechanisms, Dep: compound, POS: NOUN
# Token: mechanisms, Head: relation, Dep: conj, POS: NOUN
# Token: involved, Head: mechanisms, Dep: acl, POS: VERB
# Token: in, Head: involved, Dep: prep, POS: ADP
# Token: biological, Head: computation, Dep: amod, POS: ADJ
# Token: computation, Head: processes, Dep: nmod, POS: NOUN
# Token: and, Head: computation, Dep: cc, POS: CCONJ
# Token: mutation, Head: computation, Dep: conj, POS: NOUN
# Token: processes, Head: in, Dep: pobj, POS: NOUN
# Token: ., Head: focuses, Dep: punct, POS: PUNCT
# Token: His, Head: work, Dep: poss, POS: PRON
# Token: work, Head: delves, Dep: nsubj, POS: NOUN
# Token: delves, Head: delves, Dep: ROOT, POS: VERB
# Token: into, Head: delves, Dep: prep, POS: ADP
# Token: areas, Head: into, Dep: pobj, POS: NOUN
# Token: like, Head: areas, Dep: prep, POS: ADP
# Token: conformational, Head: dynamics, Dep: amod, POS: ADJ
# Token: dynamics, Head: like, Dep: pobj, POS: NOUN
# Token: of, Head: dynamics, Dep: prep, POS: ADP
# Token: DNA, Head: of, Dep: pobj, POS: PROPN
# Token: and, Head: DNA, Dep: cc, POS: CCONJ
# Token: RNA, Head: DNA, Dep: conj, POS: PROPN
# Token: ,, Head: delves, Dep: punct, POS: PUNCT
# Token: exploring, Head: delves, Dep: advcl, POS: VERB
# Token: the, Head: implications, Dep: det, POS: DET
# Token: implications, Head: exploring, Dep: dobj, POS: NOUN
# Token: of, Head: implications, Dep: prep, POS: ADP
# Token: DNA, Head: repair, Dep: compound, POS: NOUN
# Token: repair, Head: mechanisms, Dep: compound, POS: NOUN
# Token: mechanisms, Head: of, Dep: pobj, POS: NOUN
# Token: ,, Head: mechanisms, Dep: punct, POS: PUNCT
# Token: replication, Head: errors, Dep: compound, POS: NOUN
# Token: errors, Head: mechanisms, Dep: conj, POS: NOUN
# Token: ,, Head: errors, Dep: punct, POS: PUNCT
# Token: and, Head: errors, Dep: cc, POS: CCONJ
# Token: the, Head: impact, Dep: det, POS: DET
# Token: impact, Head: errors, Dep: conj, POS: NOUN
# Token: of, Head: impact, Dep: prep, POS: ADP
# Token: chemical, Head: modifications, Dep: compound, POS: NOUN
# Token: modifications, Head: of, Dep: pobj, POS: NOUN
# Token: such, Head: as, Dep: amod, POS: ADJ
# Token: as, Head: modifications, Dep: prep, POS: ADP
# Token: methylation, Head: as, Dep: pobj, POS: NOUN
# Token: ., Head: delves, Dep: punct, POS: PUNCT
# Token: Using, Head: examines, Dep: advcl, POS: VERB
# Token: techniques, Head: Using, Dep: dobj, POS: NOUN
# Token: such, Head: as, Dep: amod, POS: ADJ
# Token: as, Head: techniques, Dep: prep, POS: ADP
# Token: solid, Head: state, Dep: amod, POS: ADJ
# Token: -, Head: state, Dep: punct, POS: PUNCT
# Token: state, Head: NMR, Dep: nmod, POS: NOUN
# Token: and, Head: state, Dep: cc, POS: CCONJ
# Token: solution, Head: state, Dep: compound, POS: NOUN
# Token: -, Head: state, Dep: punct, POS: PUNCT
# Token: state, Head: state, Dep: conj, POS: NOUN
# Token: NMR, Head: spectroscopy, Dep: compound, POS: PROPN
# Token: spectroscopy, Head: as, Dep: pobj, POS: NOUN
# Token: ,, Head: examines, Dep: punct, POS: PUNCT
# Token: he, Head: examines, Dep: nsubj, POS: PRON
# Token: examines, Head: examines, Dep: ROOT, POS: VERB
# Token: the, Head: behaviors, Dep: det, POS: DET
# Token: behaviors, Head: examines, Dep: dobj, POS: NOUN
# Token: of, Head: behaviors, Dep: prep, POS: ADP
# Token: various, Head: nucleobases, Dep: amod, POS: ADJ
# Token: nucleobases, Head: of, Dep: pobj, POS: NOUN
# Token: including, Head: nucleobases, Dep: prep, POS: VERB
# Token: guanine, Head: including, Dep: pobj, POS: NOUN
# Token: and, Head: guanine, Dep: cc, POS: CCONJ
# Token: adenine, Head: guanine, Dep: conj, POS: NOUN
# Token: in, Head: guanine, Dep: prep, POS: ADP
# Token: polymorphic, Head: states, Dep: amod, POS: ADJ
# Token: states, Head: in, Dep: pobj, POS: NOUN
# Token: ,, Head: examines, Dep: punct, POS: PUNCT
# Token: contributing, Head: examines, Dep: advcl, POS: VERB
# Token: to, Head: contributing, Dep: prep, POS: ADP
# Token: a, Head: understanding, Dep: det, POS: DET
# Token: deeper, Head: understanding, Dep: amod, POS: ADJ
# Token: understanding, Head: to, Dep: pobj, POS: NOUN
# Token: of, Head: understanding, Dep: prep, POS: ADP
# Token: biophysical, Head: phenomena, Dep: amod, POS: ADJ
# Token: phenomena, Head: of, Dep: pobj, POS: NOUN
# Token: ., Head: examines, Dep: punct, POS: PUNCT
# Token: His, Head: investigations, Dep: poss, POS: PRON
# Token: investigations, Head: advance, Dep: nsubj, POS: NOUN
# Token: into, Head: investigations, Dep: prep, POS: ADP
# Token: the, Head: interaction, Dep: det, POS: DET
# Token: interaction, Head: into, Dep: pobj, POS: NOUN
# Token: of, Head: interaction, Dep: prep, POS: ADP
# Token: RNA, Head: of, Dep: pobj, POS: PROPN
# Token: with, Head: interaction, Dep: prep, POS: ADP
# Token: ligands, Head: with, Dep: pobj, POS: NOUN
# Token: and, Head: ligands, Dep: cc, POS: CCONJ
# Token: its, Head: flexibility, Dep: poss, POS: PRON
# Token: flexibility, Head: ligands, Dep: conj, POS: NOUN
# Token: further, Head: advance, Dep: advmod, POS: ADV
# Token: advance, Head: advance, Dep: ROOT, POS: VERB
# Token: the, Head: field, Dep: det, POS: DET
# Token: field, Head: advance, Dep: dobj, POS: NOUN
# Token: of, Head: field, Dep: prep, POS: ADP
# Token: RNA, Head: discovery, Dep: compound, POS: PROPN
# Token: -, Head: discovery, Dep: punct, POS: ADJ
# Token: targeted, Head: discovery, Dep: amod, POS: VERB
# Token: drug, Head: discovery, Dep: compound, POS: NOUN
# Token: discovery, Head: of, Dep: pobj, POS: NOUN
# Token: ,, Head: discovery, Dep: punct, POS: PUNCT
# Token: particularly, Head: concerning, Dep: advmod, POS: ADV
# Token: concerning, Head: advance, Dep: prep, POS: VERB
# Token: HIV-1, Head: concerning, Dep: pobj, POS: PROPN
# Token: ., Head: advance, Dep: punct, POS: PUNCT
# Token: Overall, Head: aims, Dep: advmod, POS: ADV
# Token: ,, Head: aims, Dep: punct, POS: PUNCT
# Token: his, Head: research, Dep: poss, POS: PRON
# Token: research, Head: aims, Dep: nsubj, POS: NOUN
# Token: aims, Head: aims, Dep: ROOT, POS: VERB
# Token: to, Head: elucidate, Dep: aux, POS: PART
# Token: elucidate, Head: aims, Dep: xcomp, POS: VERB
# Token: the, Head: properties, Dep: det, POS: DET
# Token: fundamental, Head: properties, Dep: amod, POS: ADJ
# Token: biophysical, Head: properties, Dep: amod, POS: ADJ
# Token: properties, Head: elucidate, Dep: dobj, POS: NOUN
# Token: of, Head: properties, Dep: prep, POS: ADP
# Token: nucleic, Head: acids, Dep: amod, POS: ADJ
# Token: acids, Head: of, Dep: pobj, POS: NOUN
# Token: ,, Head: elucidate, Dep: punct, POS: PUNCT
# Token: with, Head: elucidate, Dep: prep, POS: ADP
# Token: significant, Head: implications, Dep: amod, POS: ADJ
# Token: implications, Head: with, Dep: pobj, POS: NOUN
# Token: for, Head: implications, Dep: prep, POS: ADP
# Token: molecular, Head: biology, Dep: amod, POS: ADJ
# Token: biology, Head: for, Dep: pobj, POS: NOUN
# Token: ,, Head: biology, Dep: punct, POS: PUNCT
# Token: epitranscriptomics, Head: biology, Dep: conj, POS: NOUN
# Token: ,, Head: epitranscriptomics, Dep: punct, POS: PUNCT
# Token: and, Head: epitranscriptomics, Dep: cc, POS: CCONJ
# Token: therapeutic, Head: development, Dep: amod, POS: ADJ
# Token: development, Head: epitranscriptomics, Dep: conj, POS: NOUN
# Token: ., Head: aims, Dep: punct, POS: PUNCT
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="834466aec91244b7868d131ac330a1bf-0" class="displacy" width="34880" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Al-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Hashimi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">interested</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">developing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">deep,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">quantitative,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">predictive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">understanding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">cellular</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">processes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">based</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">fundamental</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">behaviors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">nucleic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">acids</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">interactions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">protein</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">binding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">partners.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">  </tspan>
#     <tspan class="displacy-t
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="58514e56b11f40818717600bd2305d73-0" class="displacy" width="13640" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Researcher:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Hashim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">M.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">Al-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Hashimi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">Research</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">Overview:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">Hashim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">M.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">Al-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Hashimi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">research</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">primarily</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">focuses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">intricate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">dynamics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">nucleic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">acids,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">especially</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">relation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">DNA</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">damage</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fi

# %% [markdown]
# # **Word Mover's Distance, Cosine Similarity, Sentiment and Tone Analysis**

# %%
# !pip install vaderSentiment
# !pip install POT
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.7.4)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 9.9 MB/s eta 0:00:00
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# Collecting POT
#   Downloading POT-0.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (32 kB)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from POT) (1.26.4)
# Requirement already satisfied: scipy>=1.6 in /usr/local/lib/python3.10/dist-packages (from POT) (1.13.1)
# Downloading POT-0.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (835 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 835.4/835.4 kB 50.3 MB/s eta 0:00:00
# Installing collected packages: POT
# Successfully installed POT-0.9.4

# %%
import nltk
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models import KeyedVectors
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import numpy as np
import gensim.downloader as api

# Load pre-trained GloVe embeddings
word_vectors = api.load("glove-wiki-gigaword-300")

# Initialize sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to calculate Word Mover's Distance for paragraphs
def calculate_wmd(paragraph1, paragraph2):
    paragraph1_tokens = [word for word in nltk.word_tokenize(paragraph1.lower()) if word in word_vectors]
    paragraph2_tokens = [word for word in nltk.word_tokenize(paragraph2.lower()) if word in word_vectors]
    return word_vectors.wmdistance(paragraph1_tokens, paragraph2_tokens)

# Function to calculate average word vectors for cosine similarity for paragraphs
def average_word_vectors(paragraph, model, num_features):
    words = nltk.word_tokenize(paragraph.lower())
    feature_vec = np.zeros((num_features,), dtype="float32")
    n_words = 0
    for word in words:
        if word in model:
            n_words += 1
            feature_vec = np.add(feature_vec, model[word])
    if n_words > 0:
        feature_vec = np.divide(feature_vec, n_words)
    return feature_vec

# Function to analyze sentiment for paragraphs
def analyze_sentiment(paragraph):
    return analyzer.polarity_scores(paragraph)
# Out:
# [==================================================] 100.0% 376.1/376.1MB downloaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-73de767a78a7> in <cell line: 9>()
#       7
#       8 # Load pre-trained GloVe embeddings
# ----> 9 word_vectors = api.load("glove-wiki-gigaword-300")
#      10
#      11 # Initialize sentiment analyzer
#
# /usr/local/lib/python3.10/dist-packages/gensim/downloader.py in load(name, return_path)
#     501         sys.path.insert(0, BASE_DIR)
#     502         module = __import__(name)
# --> 503         return module.load_data()
#     504
#     505
#
# ~/gensim-data/glove-wiki-gigaword-300/__init__.py in load_data()
#       6 def load_data():
#       7     path = os.path.join(base_dir, 'glove-wiki-gigaword-300', 'glove-wiki-gigaword-300.gz')
# ----> 8     model = KeyedVectors.load_word2vec_format(path)
#       9     return model
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1717
#    1718         """
# -> 1719         return _load_word2vec_format(
#    1720             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1721             limit=limit, datatype=datatype, no_header=no_header,
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header, binary_chunk_size)
#    2067             )
#    2068         else:
# -> 2069             _word2vec_read_text(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#    2070     if kv.vectors.shape[0] != len(kv):
#    2071         logger.info(
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in _word2vec_read_text(fin, kv, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#    1973             raise EOFError("unexpected end of input; is count incorrect or file otherwise damaged?")
#    1974         word, weights = _word2vec_line_to_vector(line, datatype, unicode_errors, encoding)
# -> 1975         _add_word_to_kv(kv, counts, word, weights, vocab_size)
#    1976
#    1977
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in _add_word_to_kv(kv, counts, word, weights, vocab_size)
#    1904 # Functions for internal use by _load_word2vec_format function
#    1905
# -> 1906 def _add_word_to_kv(kv, counts, word, weights, vocab_size):
#    1907
#    1908     if kv.has_index_for(word):
#
# KeyboardInterrupt:

# %%
# Iterate through the matches
counter=0
for test_name in matches:
    test_name_copy = test_name
    test_name = test_name.split(" ")
    test_first_name, test_last_name = test_name[0], test_name[-1]
    test_path = candidate_path+'/'+file_names_dict[(test_first_name, test_last_name)]
    with open(test_path, 'r', encoding='utf-8') as file:
        test_contents = file.read()

    # Process the entire paragraph
    reference_paragraph = matches[test_name_copy] # human written
    candidate_paragraph = test_contents # GPT Generated

    print(f"Processing paragraph for {test_name_copy}:")
    print(f"Reference Paragraph (Human Written Scraped Content): {reference_paragraph}")
    print(f"Candidate Paragraph (GPT Generated Content): {candidate_paragraph}")
    # Detecting Subtle Differences in Meaning (Word Mover's Distance)
    wmd_distance = calculate_wmd(reference_paragraph, candidate_paragraph)
    print(f"-->Word Mover's Distance between paragraphs: {wmd_distance}")

    # Cosine Similarity using Word Embeddings for Paragraphs
    reference_vector = average_word_vectors(reference_paragraph, word_vectors, 300)
    candidate_vector = average_word_vectors(candidate_paragraph, word_vectors, 300)
    cosine_sim = cosine_similarity([reference_vector], [candidate_vector])[0][0]
    print(f"-->Cosine Similarity for paragraphs: {cosine_sim}")

    # Sentiment and Tone Analysis for Paragraphs
    reference_sentiment = analyze_sentiment(reference_paragraph)
    candidate_sentiment = analyze_sentiment(candidate_paragraph)
    print("Sentiment Analysis for paragraphs:")
    print(f"-->Reference Paragraph Sentiment: {reference_sentiment}")
    print(f"-->Candidate Paragraph Sentiment: {candidate_sentiment}")

    # Compare sentiment differences
    sentiment_diff = compare_sentiment(reference_sentiment, candidate_sentiment)
    print(f"-->Sentiment Differences for paragraphs: {sentiment_diff}")
    print("==================================================")
    if counter == 0:
        break
