# %%
from transformers import BertTokenizer, BertModel
import torch
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import json

# Load pre-trained model tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Load pre-trained BERT model
model = BertModel.from_pretrained('bert-base-uncased')

# Function to get embeddings for a paragraph
def get_paragraph_embedding(paragraph):
    encoded_input = tokenizer(paragraph, return_tensors='pt', truncation=True, max_length=512)

    with torch.no_grad():
        outputs = model(**encoded_input)

    cls_embedding = outputs.last_hidden_state[:, 0, :].squeeze().numpy()
    return cls_embedding

# %%
def read_paragraphs_from_csv(file_path, name_column, paragraph_column, researchers_name):
    df = pd.read_csv(file_path)
    paragraphs = []
    for name in researchers_name:
        for _, row in df.iterrows():
            if pd.notna(row[name_column]) and name in row[name_column]:
                if pd.notna(row[paragraph_column]):
                    paragraphs.append((name, row[paragraph_column], row["Research Interests"]))
                break
    return paragraphs

def read_paragraphs_from_json(file_path, key):
    with open(file_path, 'r') as file:
        data = json.load(file)
    paragraphs = [(entry["Researcher"],entry[key], entry["Research Interests"]) for entry in data if key in entry]  # Extract paragraphs using the specified key
    return paragraphs

# %%
csv_file_path = '/content/columbia_research_faculty_extracted.csv'
json_file_path = '/content/GPT4o_summarized_researcher_profile.json'
csv_paragraph_column = "Research Introduction"
csv_name_column = "Name"
json_key = "Research Overview"
researchers_name = [
    "Joseph A. Gogos", "Jacqueline Gottlieb", "Richard S. Mann", "Mimi Shirasu-Hiza",
    "Jane Dodd", "Larry Abbott", "Christoph Kellendonk", "Vincent P. Ferrera", "Robert D. Hawkins",
    "Nikolaus Kriegeskorte", "Henry Colecraft", "Eric A. Schon", "Eric Kandel", "Jonathan A. Javitch",
    "Rui M. Costa", "Wayne Hendrickson", "Stavros Lomvardas", "Steven A. Siegelbaum", "David Sulzer",
    "Laura Landweber"
]
csv_paragraphs = read_paragraphs_from_csv(csv_file_path, csv_name_column, csv_paragraph_column, researchers_name)
csv_paragraphs.sort()
# Read paragraphs from JSON
json_paragraphs = (read_paragraphs_from_json(json_file_path, json_key))
csv_paragraphs.sort()

# %%
for i in range(len(csv_paragraphs)):
    embedding1 = get_paragraph_embedding(csv_paragraphs[i][1])
    embedding2 = get_paragraph_embedding(json_paragraphs[i][1])
    print(csv_paragraphs[i][2].split(' '))

    # Calculate cosine similarity
    overview_similarity = cosine_similarity([embedding1], [embedding2])
    embedding1 = get_paragraph_embedding(csv_paragraphs[i][2])
    embedding2 = get_paragraph_embedding(" ".join(json_paragraphs[i][2]))
    interests_similarity = cosine_similarity([embedding1], [embedding2])
    print("Name:", csv_paragraphs[i][0])
    print(f"Research Overview Cosine Similarity: {overview_similarity[0][0]}")
    print("Research Interest Cosine Similarity:", interests_similarity[0][0])
# Out:
# ['Models', 'of', 'Psychiatric', 'Disorders', 'Neurobiology', 'of', 'Cognitive', 'and', 'Motivated', 'Behaviors', 'Neurobiology', 'of', 'Disease', 'Neurobiology', 'of', 'Learning', 'and', 'Memory', 'Neurobiology', 'of', 'Psychiatric', 'Disorders', 'Neurogenetics', 'Thalamo-Cortical', 'and', 'Basal', 'Ganglia', 'Circuitry']
# Name: Christoph Kellendonk
# Research Overview Cosine Similarity: 0.8695370554924011
# Research Interest Cosine Similarity: 0.91710955
# ['Cell', 'biology', 'Learning', 'and', 'behavior', 'Neurodegeneration', 'and', 'repair', 'Neuroimmunology', 'Synapses', 'and', 'Circuits', 'Grants', 'Four', 'current', 'R01s', '(NIMH.', 'NINDS.', 'NIDA)', 'Lead', 'PI,', 'ASAP', 'Foundation', 'award', 'for', 'research', 'in', "Parkinson's", 'Multiple', 'private', 'foundation', 'awards']
# Name: David Sulzer
# Research Overview Cosine Similarity: 0.8097734451293945
# Research Interest Cosine Similarity: 0.7999315
# ['Mitochondrial', 'genetics', 'and', 'the', 'molecular', 'basis', 'of', 'human', 'mitochondrial', 'disease']
# Name: Eric A. Schon
# Research Overview Cosine Similarity: 0.7760911583900452
# Research Interest Cosine Similarity: 0.80909854
# ['Biophysics/Ion', 'Channels', 'Models', 'of', 'Psychiatric', 'Disorders', 'Neurobiology', 'of', 'Learning', 'and', 'Memory', 'Neurogenetics', 'Synapses', 'and', 'Circuits', 'Systems', 'and', 'Circuits']
# Name: Eric Kandel
# Research Overview Cosine Similarity: 0.8181913495063782
# Research Interest Cosine Similarity: 0.8851143
# ['Biophysics/Ion', 'Channels', 'Cellular/Molecular/Developmental', 'Neuroscience']
# Name: Henry Colecraft
# Research Overview Cosine Similarity: 0.8260940909385681
# Research Interest Cosine Similarity: 0.87124085
# ['Cognitive/Systems', 'Neuroscience', 'Curiosity', 'and', 'Exploration', 'Instrinsic', 'Motivation', 'Neurophysiology', 'Reasoning', 'and', 'Decision', 'Making', 'Systems', 'and', 'Circuits', 'Grants', '2016-2019', 'Understanding', 'curiosity:', 'biological,', 'behavioral', 'and', 'computational', 'mechanisms', 'Human', 'Frontiers', 'Science', 'Program', '(Role:', 'co-PI,', 'with', 'Oudeyer,', 'Kidd)', '2012-2017', 'Attentional', 'control', 'by', 'uncertainty', 'and', 'reward:', 'parietal', 'and', 'frontal', 'mechanisms', 'National', 'Institute', 'of', 'Mental', 'Health', '(Role:', 'PI)', '2015-2020', 'Top-down', 'selection', 'of', 'task-relevant', 'cues:', 'neural', 'mechanisms', 'in', 'the', 'frontal', 'and', 'parietal', 'lobes', 'National', 'Eye', 'Institute', '(Role:', 'PI)', '2015-2016', 'Determinants', 'of', 'attention', 'and', 'information', 'seeking', 'in', 'human', 'economic', 'choice', 'Presidential', 'Scholars', 'in', 'Society', 'and', 'Neuroscience', 'Faculty', 'Seed', 'Grants', 'for', 'Interdisciplinary', 'Projects', 'in', 'Society', 'and', 'Neuroscience', '(Role:', 'co-PI,', 'with', 'Micahel', 'Woodford)', '2015-2017', 'Population', 'dynamics', 'of', 'reward', 'and', 'uncertainty', 'McKnight', 'Memory', 'and', 'Cognitive', 'Disorders', 'Award', '(Role:', 'PI)', '2016-2019', 'Neural', 'mechanisms', 'of', 'curiosity', 'and', 'attention', 'INRIA,', 'Bordeaux,', 'France', '(Role:', 'co-PI,', 'with', 'Oudeyer', 'and', 'Lopes)']
# Name: Jacqueline Gottlieb
# Research Overview Cosine Similarity: 0.8379340171813965
# Research Interest Cosine Similarity: 0.80597824
# ['Axon', 'Pathfinding', 'and', 'Synaptogenesis', 'Cell', 'Specification', 'and', 'Differentiation', 'Cellular/Molecular/Developmental', 'Neuroscience', 'Synapses', 'and', 'Circuits']
# Name: Jane Dodd
# Research Overview Cosine Similarity: 0.6192790865898132
# Research Interest Cosine Similarity: 0.8610776
# ['Biophysics/Ion', 'Channels', 'G-protein', 'Coupled', 'Receptors:', 'Structural', 'Bases', 'for', 'Pharmacological', 'Specificity', 'and', 'Function', 'Models', 'of', 'Psychiatric', 'Disorders', 'Neurobiology', 'of', 'Disease', 'Neurotransmitter', 'Transporters:', 'Biophysics,', 'Biochemistry', 'and', 'Regulation']
# Name: Jonathan A. Javitch
# Research Overview Cosine Similarity: 0.8025346994400024
# Research Interest Cosine Similarity: 0.88524246
# ['Models', 'of', 'Psychiatric', 'Disorders', 'Neurobiology', 'of', 'Disease', 'Neurogenetics', 'Synapses', 'and', 'Circuits']
# Name: Joseph A. Gogos
# Research Overview Cosine Similarity: 0.8077750205993652
# Research Interest Cosine Similarity: 0.84888715
# ['Cognitive/Systems', 'Neuroscience', 'Computation', 'and', 'Theory', 'Neurobiology', 'of', 'Learning', 'and', 'Memory', 'Theoretical', 'Neuroscience']
# Name: Larry Abbott
# Research Overview Cosine Similarity: 0.7285942435264587
# Research Interest Cosine Similarity: 0.9331203
# ['Genome', 'Evolution', 'Genome', 'Rearrangement', 'Molecular', 'Evolution', 'Small', 'and', 'Long', 'Noncoding', 'RNAs']
# Name: Laura Landweber
# Research Overview Cosine Similarity: 0.8195253610610962
# Research Interest Cosine Similarity: 0.91812074
# ['Cellular/Molecular/Developmental', 'Neuroscience', 'Circadian-regulated', 'metabolism', 'Glial', 'Development', 'and', 'Pathology', 'Mitochondria', 'Biology', 'and', 'Disease', 'Neural', 'Degeneration', 'and', 'Repair', 'Neurobiology', 'of', 'Learning', 'and', 'Memory', 'Neurogenetics', 'Sleep', 'Grants', '2011', 'March', 'of', 'Dimes,', 'Basil', "O'Connor", 'Award', '2012', 'Hirschl', 'Career', 'Award', '2013', 'NIH', 'R01', 'GM105775', '2013', 'NIH', 'R01', 'AG045842']
# Name: Mimi Shirasu-Hiza
# Research Overview Cosine Similarity: 0.7888432741165161
# Research Interest Cosine Similarity: 0.85636723
# ['Brain', 'Imaging', 'Cognitive/Systems', 'Neuroscience', 'Sensory', 'Physiology', 'Theoretical', 'Neuroscience']
# Name: Nikolaus Kriegeskorte
# Research Overview Cosine Similarity: 0.7403086423873901
# Research Interest Cosine Similarity: 0.90251786
# ['Axon', 'Pathfinding', 'and', 'Synaptogenesis', 'Cell', 'Specification', 'and', 'Differentiation', 'Cellular/Molecular/Developmental', 'Neuroscience', 'Neurogenetics', 'Stem', 'Cell', 'Biology']
# Name: Richard S. Mann
# Research Overview Cosine Similarity: 0.7577525973320007
# Research Interest Cosine Similarity: 0.9319292
# ['Neurobiology', 'of', 'Learning', 'and', 'Memory', 'Synapses', 'and', 'Circuits', 'Grants', 'Genomic', 'bases', 'of', 'behavioral', 'learning:', 'Single', 'cell', 'approaches', '-', 'Project', 'Dates:', '07/01/11', 'to', '01/31/16', 'New', 'synapse', 'formation', 'during', 'long-term', 'plasticity', '-', 'Project', 'Dates:', '07/01/15', 'to', '06/30/16', 'Neurotrophins,', 'spontaneous', 'release,', 'and', 'synaptic', 'growth', 'cascades', '-', 'Project', 'Dates:', '07/01/13', 'to', '06/30/18']
# Name: Robert D. Hawkins
# Research Overview Cosine Similarity: 0.8045963048934937
# Research Interest Cosine Similarity: 0.79449403
# ['Behavioral', 'Genetics', 'electrophysiology']
# Name: Rui M. Costa
# Research Overview Cosine Similarity: 0.8432714939117432
# Research Interest Cosine Similarity: 0.84631073
# ['Sensory', 'Physiology', 'Snapses', 'and', 'Circuits']
# Name: Stavros Lomvardas
# Research Overview Cosine Similarity: 0.7926662564277649
# Research Interest Cosine Similarity: 0.75995994
# ['Biophysics/Ion', 'Channels', 'Models', 'of', 'Psychiatric', 'Disorders', 'Molecular', 'Studies', 'of', 'Ion', 'Channel', 'Structure', 'and', 'Function', 'Neurobiology', 'of', 'Learning', 'and', 'Memory', 'Synapses', 'and', 'Circuits', 'Synaptic', 'Transmission', 'and', 'Plasticity', 'in', 'the', 'Mammalian', 'Brain']
# Name: Steven A. Siegelbaum
# Research Overview Cosine Similarity: 0.7788649797439575
# Research Interest Cosine Similarity: 0.9043264
# ['Cognitive/Systems', 'Neuroscience', 'Systems', 'and', 'Circuits']
# Name: Vincent P. Ferrera
# Research Overview Cosine Similarity: 0.8645504117012024
# Research Interest Cosine Similarity: 0.890724
# ['Macromolecular', 'structure', 'with', 'an', 'aim', 'toward', 'in-depth', 'understanding', 'of', 'biological', 'activity.']
# Name: Wayne Hendrickson
# Research Overview Cosine Similarity: 0.8335502743721008
# Research Interest Cosine Similarity: 0.77678484

# %% [markdown]
# # **Research Interest Semantic Similarity Comparison Based On Ontology**

# %%
pip install owlready2 nltk
# Out:
# Requirement already satisfied: owlready2 in /usr/local/lib/python3.10/dist-packages (0.46)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)

# %%
import owlready2
import nltk
from owlready2 import get_ontology
from math import log
from itertools import product

# Load information content file from NLTK
nltk.download('wordnet_ic')
brown_ic = nltk.corpus.wordnet_ic.ic('ic-brown.dat')

# Load the Gene Ontology
ontology = get_ontology("http://purl.obolibrary.org/obo/go.owl").load()

# Function to get the IC of a term
def get_information_content(term, ic_dict):
    if term in ic_dict:
        return ic_dict[term]
    else:
        return -log(1e-10)

# Function to find the most informative common ancestor (MICA)
def get_mica(term1, term2, ic_dict):
    ancestors1 = set(term1.ancestors())
    ancestors2 = set(term2.ancestors())
    common_ancestors = ancestors1.intersection(ancestors2)
    if not common_ancestors:
        return None, 0.0
    mica = max(common_ancestors, key=lambda ancestor: get_information_content(ancestor, ic_dict))
    return mica, get_information_content(mica, ic_dict)

# Function to calculate Resnik similarity between two terms
def resnik_similarity(term1, term2, ic_dict):
    mica, ic = get_mica(term1, term2, ic_dict)
    return ic

# Precompute the information content dictionary from ontology
ic_dict = {}
for term in ontology.classes():
    ic_dict[term] = get_information_content(term, brown_ic)

# Function to map terms to ontology classes
def map_to_ontology(term, ontology):
    return ontology.search_one(label=term)

# Iterate through the paragraphs and compute similarities
for i in range(len(csv_paragraphs)):
    name = csv_paragraphs[i][0]

    # Extract and clean human research interests
    interests_terms = csv_paragraphs[i][2].split(" ")
    interests_terms_human = [term for term in interests_terms if term not in ["and", "the", "of"]]
    print("Human",interests_terms_human)

    interests_terms_gpt = json_paragraphs[i][2]
    print("GPT",interests_terms_gpt)

    # Map terms to ontology classes
    mapped_terms1 = [map_to_ontology(term, ontology) for term in interests_terms_human]
    mapped_terms2 = [map_to_ontology(term, ontology) for term in interests_terms_gpt]
    print(mapped_terms1)
    print(mapped_terms2)
    pairwise_similarities = []
    for term1, term2 in product(mapped_terms1, mapped_terms2):
        if term1 and term2:
            similarity = resnik_similarity(term1, term2, ic_dict)
            pairwise_similarities.append(similarity)
    # print(pairwise_similarities)
    if pairwise_similarities:
        overall_similarity = sum(pairwise_similarities) / len(pairwise_similarities)
    else:
        overall_similarity = 0.0

    print(f"Overall similarity between Research Interests for {name}: {overall_similarity}")
# Out:
# [nltk_data] Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]   Package wordnet_ic is already up-to-date!
# Human ['Models', 'Psychiatric', 'Disorders', 'Neurobiology', 'Cognitive', 'Motivated', 'Behaviors', 'Neurobiology', 'Disease', 'Neurobiology', 'Learning', 'Memory', 'Neurobiology', 'Psychiatric', 'Disorders', 'Neurogenetics', 'Thalamo-Cortical', 'Basal', 'Ganglia', 'Circuitry']
# GPT ['Neural Circuitry', 'Neurotransmitter Systems', 'Cognitive Neuroscience', 'Motor Function', 'Neurodevelopment', 'Neuroplasticity', 'Psychiatric Disorders', 'Molecular Neuroscience', 'Behavioral Neuroscience', 'Synaptic Transmission']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Christoph Kellendonk: 0.0
# Human ['Cell', 'biology', 'Learning', 'behavior', 'Neurodegeneration', 'repair', 'Neuroimmunology', 'Synapses', 'Circuits', 'Grants', 'Four', 'current', 'R01s', '(NIMH.', 'NINDS.', 'NIDA)', 'Lead', 'PI,', 'ASAP', 'Foundation', 'award', 'for', 'research', 'in', "Parkinson's", 'Multiple', 'private', 'foundation', 'awards']
# GPT ['Neurotransmission', 'Neurodegeneration', 'Neurodevelopmental Disorders', "Parkinson's Disease", 'Autism Spectrum Disorders', 'Mitochondrial Function', 'Immune Responses in the Brain', 'Dopamine Signaling', 'Acetylcholine Signaling', 'Synaptic Plasticity']
# [None, None, None, obo.GO_0007610, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for David Sulzer: 0.0
# Human ['Mitochondrial', 'genetics', 'molecular', 'basis', 'human', 'mitochondrial', 'disease']
# GPT ['Mitochondrial Diseases', 'Neurodegeneration', 'Metabolic Disorders', 'Mitochondrial DNA Mutations', 'Cellular Energy Production', 'Apoptosis', 'Nuclear-Mitochondrial Interactions', "Parkinson's Disease", "Alzheimer's Disease", 'Therapeutic Strategies for Mitochondrial Dysfunction']
# [None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Eric A. Schon: 0.0
# Human ['Biophysics/Ion', 'Channels', 'Models', 'Psychiatric', 'Disorders', 'Neurobiology', 'Learning', 'Memory', 'Neurogenetics', 'Synapses', 'Circuits', 'Systems', 'Circuits']
# GPT ['Memory Storage', 'Synaptic Plasticity', 'Neural Circuits', 'Learning and Memory', 'Electrophysiology', 'Molecular Biology', 'Cognitive Impairments', 'Memory Disorders', 'Behavioral Neuroscience', 'Biological Basis of Memory']
# [None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Eric Kandel: 0.0
# Human ['Biophysics/Ion', 'Channels', 'Cellular/Molecular/Developmental', 'Neuroscience']
# GPT ['Ion Channels', 'Electrical Signaling', 'Cardiac Arrhythmias', 'Neurological Disorders', 'Electrophysiology', 'Molecular Biology', 'Biophysics', 'Ion Channel Regulation', 'Therapeutic Modulation of Ion Channels', 'Disease Mechanisms']
# [None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Henry Colecraft: 0.0
# Human ['Cognitive/Systems', 'Neuroscience', 'Curiosity', 'Exploration', 'Instrinsic', 'Motivation', 'Neurophysiology', 'Reasoning', 'Decision', 'Making', 'Systems', 'Circuits', 'Grants', '2016-2019', 'Understanding', 'curiosity:', 'biological,', 'behavioral', 'computational', 'mechanisms', 'Human', 'Frontiers', 'Science', 'Program', '(Role:', 'co-PI,', 'with', 'Oudeyer,', 'Kidd)', '2012-2017', 'Attentional', 'control', 'by', 'uncertainty', 'reward:', 'parietal', 'frontal', 'mechanisms', 'National', 'Institute', 'Mental', 'Health', '(Role:', 'PI)', '2015-2020', 'Top-down', 'selection', 'task-relevant', 'cues:', 'neural', 'mechanisms', 'in', 'frontal', 'parietal', 'lobes', 'National', 'Eye', 'Institute', '(Role:', 'PI)', '2015-2016', 'Determinants', 'attention', 'information', 'seeking', 'in', 'human', 'economic', 'choice', 'Presidential', 'Scholars', 'in', 'Society', 'Neuroscience', 'Faculty', 'Seed', 'Grants', 'for', 'Interdisciplinary', 'Projects', 'in', 'Society', 'Neuroscience', '(Role:', 'co-PI,', 'with', 'Micahel', 'Woodford)', '2015-2017', 'Population', 'dynamics', 'reward', 'uncertainty', 'McKnight', 'Memory', 'Cognitive', 'Disorders', 'Award', '(Role:', 'PI)', '2016-2019', 'Neural', 'mechanisms', 'curiosity', 'attention', 'INRIA,', 'Bordeaux,', 'France', '(Role:', 'co-PI,', 'with', 'Oudeyer', 'Lopes)']
# GPT ['Attention', 'Decision-Making', 'Learning', 'Cognitive Control', 'Prefrontal Cortex', 'Behavioral Neuroscience', 'Neurophysiology', 'Information Processing', 'Mental Health Disorders', 'Cognitive Function']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, obo.IAO_0000030, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Jacqueline Gottlieb: 0.0
# Human ['Axon', 'Pathfinding', 'Synaptogenesis', 'Cell', 'Specification', 'Differentiation', 'Cellular/Molecular/Developmental', 'Neuroscience', 'Synapses', 'Circuits']
# GPT ['Neural Circuit Development', 'Spinal Cord Function', 'Motor Control', 'Sensory Processing', 'Genetic Techniques', 'Molecular Signaling Pathways', 'Imaging Techniques', 'Spinal Cord Injuries', 'Regenerative Therapies', 'Neural Development']
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Jane Dodd: 0.0
# Human ['Biophysics/Ion', 'Channels', 'G-protein', 'Coupled', 'Receptors:', 'Structural', 'Bases', 'for', 'Pharmacological', 'Specificity', 'Function', 'Models', 'Psychiatric', 'Disorders', 'Neurobiology', 'Disease', 'Neurotransmitter', 'Transporters:', 'Biophysics,', 'Biochemistry', 'Regulation']
# GPT ['Neurotransmitter Receptors', 'G-Protein-Coupled Receptors (GPCRs)', 'Signal Transduction', 'Neuropsychiatric Disorders', 'Biochemistry', 'Pharmacology', 'Structural Biology', 'Receptor Regulation', 'Schizophrenia', 'Depression']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Jonathan A. Javitch: 0.0
# Human ['Models', 'Psychiatric', 'Disorders', 'Neurobiology', 'Disease', 'Neurogenetics', 'Synapses', 'Circuits']
# GPT ['Neuropsychiatric Disorders', 'Schizophrenia', 'Autism', 'Genetic Mutations', 'Neural Circuits', 'Behavioral Approaches', 'Molecular Neuroscience', 'Animal Models', 'Therapeutic Targets', 'Treatment Strategies']
# [None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Joseph A. Gogos: 0.0
# Human ['Cognitive/Systems', 'Neuroscience', 'Computation', 'Theory', 'Neurobiology', 'Learning', 'Memory', 'Theoretical', 'Neuroscience']
# GPT ['Computational Neuroscience', 'Neural Networks', 'Brain Function', 'Information Processing', 'Learning and Memory', 'Neural Dynamics', 'Computational Models', 'Neural Activity', 'Artificial Intelligence', 'Neural Network Design']
# [None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Larry Abbott: 0.0
# Human ['Genome', 'Evolution', 'Genome', 'Rearrangement', 'Molecular', 'Evolution', 'Small', 'Long', 'Noncoding', 'RNAs']
# GPT ['Genome Rearrangement', 'RNA-Guided DNA Elimination', 'Genome Evolution', 'Genome Regulation', 'Non-Coding RNAs', 'Transposable Elements', 'Genomics', 'Molecular Biology', 'Bioinformatics', 'Cellular Function']
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Laura Landweber: 0.0
# Human ['Cellular/Molecular/Developmental', 'Neuroscience', 'Circadian-regulated', 'metabolism', 'Glial', 'Development', 'Pathology', 'Mitochondria', 'Biology', 'Disease', 'Neural', 'Degeneration', 'Repair', 'Neurobiology', 'Learning', 'Memory', 'Neurogenetics', 'Sleep', 'Grants', '2011', 'March', 'Dimes,', 'Basil', "O'Connor", 'Award', '2012', 'Hirschl', 'Career', 'Award', '2013', 'NIH', 'R01', 'GM105775', '2013', 'NIH', 'R01', 'AG045842']
# GPT ['Sleep', 'Immune Function', 'Aging', 'Health and Longevity', 'Genetic Mechanisms', 'Molecular Mechanisms', 'Drosophila Model', 'Sleep Regulation', 'Disease Prevention', 'Therapeutic Strategies']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Mimi Shirasu-Hiza: 0.0
# Human ['Brain', 'Imaging', 'Cognitive/Systems', 'Neuroscience', 'Sensory', 'Physiology', 'Theoretical', 'Neuroscience']
# GPT ['Computational Neuroscience', 'Neuroimaging', 'Perception', 'Object Recognition', 'Brain Representation', 'Information Processing', 'fMRI', 'Machine Learning', 'Cognitive Neuroscience', 'Neural Computation']
# [None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Nikolaus Kriegeskorte: 0.0
# Human ['Axon', 'Pathfinding', 'Synaptogenesis', 'Cell', 'Specification', 'Differentiation', 'Cellular/Molecular/Developmental', 'Neuroscience', 'Neurogenetics', 'Stem', 'Cell', 'Biology']
# GPT ['Developmental Biology', 'Transcription Factors', 'Gene Regulation', 'Hox Proteins', 'Embryogenesis', 'Drosophila Genetics', 'Genome Engineering', 'Biophysical Modeling', 'Evolution of Gene Regulatory Networks', 'Molecular Mechanisms of Development']
# [None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Richard S. Mann: 0.0
# Human ['Neurobiology', 'Learning', 'Memory', 'Synapses', 'Circuits', 'Grants', 'Genomic', 'bases', 'behavioral', 'learning:', 'Single', 'cell', 'approaches', '-', 'Project', 'Dates:', '07/01/11', 'to', '01/31/16', 'New', 'synapse', 'formation', 'during', 'long-term', 'plasticity', '-', 'Project', 'Dates:', '07/01/15', 'to', '06/30/16', 'Neurotrophins,', 'spontaneous', 'release,', 'synaptic', 'growth', 'cascades', '-', 'Project', 'Dates:', '07/01/13', 'to', '06/30/18']
# GPT ['Learning and Memory', 'Synaptic Plasticity', 'Neurotransmitters', 'Signaling Pathways', 'Long-Term Memory', 'Electrophysiology', 'Behavioral Neuroscience', 'Molecular Biology', 'Aging and Memory', 'Neurological Disorders']
# [None, None, None, None, None, None, None, None, None, None, None, obo.CL_0000000, None, None, None, None, None, None, None, None, obo.GO_0045202, None, None, None, None, None, None, None, None, None, None, None, None, None, None, obo.GO_0040007, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Robert D. Hawkins: 0.0
# Human ['Behavioral', 'Genetics', 'electrophysiology']
# GPT ['Motor Control', 'Action and Behavior', 'Habit Formation', 'Sensory-Motor Integration', 'Neural Circuits', 'Electrophysiology', 'Behavioral Neuroscience', 'Genetic Approaches', 'Movement Disorders', "Therapeutic Strategies for Parkinson's Disease"]
# [None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Rui M. Costa: 0.0
# Human ['Sensory', 'Physiology', 'Snapses', 'Circuits']
# GPT ['Olfactory Receptors', 'Gene Regulation', 'Epigenetics', 'Genomic Architecture', 'Nuclear Compartmentalization', 'Sensory Biology', 'Chromatin Immunoprecipitation', 'High-Throughput Sequencing', 'Imaging Techniques', 'Environmental Effects on Gene Expression']
# [None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Stavros Lomvardas: 0.0
# Human ['Biophysics/Ion', 'Channels', 'Models', 'Psychiatric', 'Disorders', 'Molecular', 'Studies', 'Ion', 'Channel', 'Structure', 'Function', 'Neurobiology', 'Learning', 'Memory', 'Synapses', 'Circuits', 'Synaptic', 'Transmission', 'Plasticity', 'in', 'Mammalian', 'Brain']
# GPT ['Synaptic Transmission', 'Synaptic Plasticity', 'Ion Channels', 'Neurotransmitter Receptors', 'Memory Formation', 'Electrophysiology', 'Genetic Techniques', 'Imaging Techniques', 'Neural Communication', 'Learning and Memory Disorders']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Steven A. Siegelbaum: 0.0
# Human ['Cognitive/Systems', 'Neuroscience', 'Systems', 'Circuits']
# GPT ['Visual Perception', 'Decision-Making', 'Neural Circuits', 'Sensory Processing', 'Electrophysiology', 'Behavioral Neuroscience', 'Computational Modeling', 'Attention', 'Sensory Information Integration', 'Mechanisms of Perception']
# [None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Vincent P. Ferrera: 0.0
# Human ['Macromolecular', 'structure', 'with', 'an', 'aim', 'toward', 'in-depth', 'understanding', 'biological', 'activity.']
# GPT ['Structural Biology', 'Protein Complexes', 'X-ray Crystallography', 'Signal Transduction', 'Cellular Regulation', 'Biophysical Techniques', 'Protein Function', 'Molecular Mechanisms', 'Therapeutic Strategies', 'Protein Interactions']
# [None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None]
# Overall similarity between Research Interests for Wayne Hendrickson: 0.0
